# %%
# %matplotlib inline
from __future__ import print_function
from dolfin import *
from dolfin_adjoint import *
import numpy as np
import os, sys
import scipy.io as scio
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import colors

set_log_level(ERROR) 

class InterpolatedParameter(Expression):
    '''
        Class to get tumor cell distributions by interpolating based off matrices of tumor cell data
    '''
    def __init__(self,X,Y,image,**kwargs):
        self.X = X # A numpy array giving the X-spacing of the image
        self.Y = Y # Same for Y
        self.image = image # The image of measured material property    
    def eval_cell(self,values,x,cell):
        interp_handle = RegularGridInterpolator((self.X,self.Y),self.image)
        values[0] = interp_handle(x)
        
def interp(file_loc,mat_name):
    print("Interpolating "+mat_name+"...")
    mat = scio.loadmat(file_loc)[mat_name]
    mat = np.fliplr(mat.T)/theta  # Needs to be adjusted to fit the mesh correctly; also scaled
    x,y = mat.shape[0], mat.shape[1]
    mat_interp = InterpolatedParameter(np.linspace(1,x,x),np.linspace(1,y,y),mat,degree=1)
    return interpolate(mat_interp,V)

def vis_obs(initial_p,target_p,title1,title2):
    '''
        Compare two quantity plots, for example initial vs. target cellularity
        Accepts titles for each plot
    '''
    print("Plotting initial condition and target...")
    target_p = interpolate(target_p,V)
    cm1 = colors.ListedColormap([[0,1,0,1],[0,0,0,1],[1,0,0,1]])    
    cm2 = cm.get_cmap('jet')
    plt.figure()
    plt.subplot(1,2,1)
    plt.title(title1)
    plot(initial_p,cmap=cm2)
 
    plt.subplot(1,2,2)
    plt.title(title2)
    plot(target_p,cmap=cm2)
    plt.show()

def forward(initial_p,record=False):
    """ 
        Here, we define the forward problem. 
    """
    
    '''
        - E(u) returns the Green-Lagrange strain tensor
        - sigma(...) returns the actual stress tensor
        - sigma_form(...) returns the stress tensor based on the cells (phi), elasticity coefficients, and a coefficient beta
        - vonmises(...) calculates the von Mises stress based on the actual stress tensor
    '''
    print("Running the forward problem...")
    
    # Define functions
    def E(u):
        return 0.5*(nabla_grad(u) + nabla_grad(u).T)
    def sigma(u):
        I = Identity(2)             # Identity tensor
        F = I + grad(u)             # Deformation gradient
        B = F*F.T
        C = F.T*F
        J = det(F)
        I1 = tr(C)
        sigma = lmbda*(J-1)*I+mu*(B-1./2*I1*I)/(J**(5./3))
        return sigma
    def vonmises(u):
        s = sigma(u) - (1./2)*tr(sigma(u))*Identity(2)  # deviatoric stress
        von_Mises = sqrt(3./2*inner(s, s))
        return project(von_Mises, V)
    def sigma_form(u, phi):
        I = Identity(2)             # Identity tensor
        F = I + grad(u)             # Deformation gradient
        Fs = F/(1+beta*phi)
        Bs = Fs*Fs.T
        Js  = det(Fs)
        return 1/(1+beta*phi)*(mu/(Js**(5./3))*(Bs-1./2*tr(Bs)*I)+lmbda*(Js-1)*I)

   
    k.rename('k','k field')              # field of growth rate, treated as a local parameter here
    p_n = Function(V) # current distribution of cell density (phi_T)
    p_n = interpolate(initial_p,V)
    p_n.rename('phi_T','tumor fraction')
    p = Function(V)
    q = TestFunction(V)
    
    U = VectorFunctionSpace(mesh,'Lagrange',1)
    def boundary(x, on_boundary):
        return on_boundary
    bc = DirichletBC(U, Constant((0.,0.)), boundary)
    u = Function(U) 
    u.rename('u','displacement')
    v = TestFunction(U)
    F_LE = inner(sigma_form(u, p_n), E(v))*dx
    def le():
        print("Solving hyper elastic problem...")
        solve(F_LE==0, u, bc)
        return u

    disp = le()
    vm = vonmises(disp)
    D = D0*exp(-gammaD*vm)
    F_RD = (1/dt)*(p - p_n)*q*dx + D*dot(grad(q),grad(p))*dx - k*p*(1 - p)*q*dx  

    # Prepare the solution
    t = 0.
    if record:        # save the current solution, k field, displacement, and diffusion
        file_results.write(p_n,t)
        file_results.write(u,t)
        file_results.write(k,t)
        D_proj = project(D,V)
        vm.rename("vm","Von Mises")
        D_proj.rename("D","diffusion coefficient")
        file_results.write(vm,t)
        file_results.write(D_proj,t)
        
    for n in range(num_steps):
        # Update current time
        t += dt
        
        # Compute solution
        print("Solving reaction diffusion for time = "+str(t))
        solve(F_RD == 0, p) # with trivial Neumann BC

        # Update previous solution
        p_n.assign(p)
        disp = le()
        vm   = vonmises(disp)
        D    = D0*exp(-gammaD*vm)
        
        if record:        # save the current solution, k field, displacement, and diffusion
            file_results.write(p_n,t)
            file_results.write(u,t)
            file_results.write(k,t)
            D_proj = project(D,V)
            D_proj.rename("D","diffusion coefficient")
            file_results.write(vm,t)
            file_results.write(D_proj,t)

    return p

# Callback function for the optimizer
# Writes intermediate results to a logfile
def eval_cb(j, m):
    """ The callback function keeping a log """
    print("objective = %15.10e " % j)

def objective(p, target_p, r_coeff1, r_coeff2):
    return assemble(inner(p-target_p, p-target_p)*dx) + r_coeff1*assemble(k*k*dx) + r_coeff2*assemble(dot(grad(k),grad(k))*dx)

def optimize(dbg=False):
    """ The optimization routine """
    print("Optimizing...")
    # Define the control
    m = [Control(k), Control(D0)]
    
    # Execute first time to annotate and record the tape
    p = forward(initial_p,False)

    J = objective(p, target_p, r_coeff1, r_coeff2)

    # Prepare the reduced functional
    rf = ReducedFunctional(J,m,eval_cb_post=eval_cb)

    # upper and lower bound for the parameter field
    k_lb, k_ub = Function(V), Function(V)
    k_lb.vector()[:] = 0.
    k_ub.vector()[:] = 20.
    D_lb = Constant(0.)
    D_ub = Constant(20.)

    # Run the optimization
    m_opt = minimize(rf,method='L-BFGS-B', bounds = [ [k_lb, D_lb], [k_ub, D_ub] ], tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
    
    # Run the optimization
    #m_opt = minimize(rf,method='L-BFGS-B', tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
    
    return m_opt

#########################################################################
# MAIN 
#########################################################################
t1         = time()
case       = 0
r_coeff1   = 0.01
r_coeff2   = 0.01
input_dir  = "../rat-data/rat05/"
output_dir = './output/rat05'

# Prepare output file
file_results = XDMFFile(os.path.join(output_dir,'optimal.xdmf'))
file_results.parameters["flush_output"] = True
file_results.parameters["functions_share_mesh"] = True

# Prepare a mesh
mesh = Mesh(input_dir+"gmsh.xml")
V    = FunctionSpace(mesh, 'CG', 1)

# Model parameters
T             = 1.0             # final time 
num_steps     = 100              # number of time steps
dt            = T/num_steps     # time step size
theta         = 50970.            # carrying capacity - normalize data by this
mu            = .42          # kPa, bulk shear modulus
nu            = .45
lmbda         = 2*mu*nu/(1-2*nu)
beta          = 1.
gammaD = Constant(1.2)    # initial guess of gamma_D

# Parameters to be optimized
D0     = Constant(10.)   # mobility or diffusion coefficient
k0     = Constant(2.)    # growth rate initial guess
k      = project(k0,V)

# Load initial tumor condition data
initial_p = interp(input_dir+"ic.mat","ic")
initial_p.rename('initial','tumor at day 0')
# target_p  = interp(input_dir+"tumor_t2.mat","tumor")  
# target_p.rename('target','tumor at day 2')

target_p = forward(initial_p, True)

D0     = Constant(8.)   # mobility or diffusion coefficient
k0     = Constant(8.)    # growth rate initial guess
k      = project(k0,V)

# Visualize initial cellularity and target cellularity
vis_obs(initial_p,target_p,'initial','target') 

# Optimization module
[k, D0] = optimize() # optimize the k field, gammaD, and D0 using the adjoint method provided by adjoint_dolfin
model_p = forward(initial_p,False) # run the forward model using the optimized k field
print('norm(k_opt) = '+str(norm(k)))
print('J_opt = '+str(objective(model_p, target_p, r_coeff1, r_coeff2)))
print('J_opt (without regularization) = '+str(objective(model_p, target_p, 0., 0.)))
print('gamma_D = '+str(gammaD.values()[0]))
print('D0 = '+str(D0.values()[0]))
print('Elapsed time is ' + str((time()-t1)/60) + ' minutes')
vis_obs(model_p,target_p,'model','actual')
plot(k)
# Out:
# Interpolating ic...
# Running the forward problem...
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.01
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.02
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.03
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.04
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.05
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.06
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.07
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.08
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.09
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.1
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.11
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.12
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.13
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.14
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.15
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.16
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.17
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.18
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.19
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.2
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.21
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.22
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.23
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.24
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.25
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.26
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.27
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.28
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.29
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.3
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.31
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.32
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.33
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.34
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.35
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.36
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.37
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.38
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.39
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.4
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.41
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.42
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.43
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.44
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.45
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.46
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.47
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.48
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.49
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.5
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.51
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.52
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.53
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.54
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.55
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.56
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.57
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.58
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.59
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.6
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.61
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.62
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.63
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.64
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.65
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.66
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.67
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.68
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.69
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.7
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.71
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.72
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.73
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.74
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.75
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.76
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.77
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.78
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.79
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.8
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.81
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.82
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.83
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.84
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.85
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.86
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.87
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.88
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.89
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.9
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.91
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.92
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.93
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.94
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.95
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.96
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.97
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.98
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.99
# Solving linear elastic problem...
# Solving reaction diffusion for time = 1.0
# Solving linear elastic problem...
# Plotting initial condition and target...
# Optimizing...
# Running the forward problem...
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.01
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.02
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.03
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.04
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.05
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.06
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.07
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.08
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.09
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.1
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.11
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.12
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.13
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.14
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.15
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.16
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.17
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.18
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.19
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.2
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.21
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.22
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.23
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.24
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.25
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.26
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.27
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.28
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.29
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.3
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.31
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.32
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.33
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.34
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.35
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.36
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.37
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.38
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.39
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.4
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.41
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.42
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.43
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.44
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.45
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.46
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.47
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.48
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.49
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.5
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.51
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.52
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.53
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.54
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.55
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.56
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.57
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.58
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.59
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.6
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.61
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.62
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.63
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.64
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.65
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.66
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.67
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.68
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.69
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.7
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.71
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.72
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.73
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.74
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.75
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.76
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.77
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.78
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.79
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.8
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.81
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.82
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.83
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.84
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.85
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.86
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.87
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.88
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.89
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.9
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.91
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.92
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.93
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.94
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.95
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.96
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.97
# Solving linear elastic problem...

# %%
plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7f65f67fca50>,
#  <matplotlib.lines.Line2D at 0x7f65dafbdf10>]

# %%
plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7fae2256cd50>,
#  <matplotlib.lines.Line2D at 0x7fae2256cf10>]
