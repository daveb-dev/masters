# %%
# %matplotlib inline
from __future__ import print_function
from dolfin import *
from dolfin_adjoint import *
import numpy as np
import os, sys
import scipy.io as scio
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import colors

set_log_level(ERROR) 

class InterpolatedParameter(Expression):
    '''
        Class to get tumor cell distributions by interpolating based off matrices of tumor cell data
    '''
    def __init__(self,X,Y,image,**kwargs):
        self.X = X # A numpy array giving the X-spacing of the image
        self.Y = Y # Same for Y
        self.image = image # The image of measured material property    
    def eval_cell(self,values,x,cell):
        interp_handle = RegularGridInterpolator((self.X,self.Y),self.image)
        values[0] = interp_handle(x)
        
def interp(file_loc,mat_name):
    print("Interpolating "+mat_name+"...")
    mat = scio.loadmat(file_loc)[mat_name]
    mat = np.fliplr(mat.T)/theta  # Needs to be adjusted to fit the mesh correctly; also scaled
    x,y = mat.shape[0], mat.shape[1]
    mat_interp = InterpolatedParameter(np.linspace(1,x,x),np.linspace(1,y,y),mat,degree=1)
    return interpolate(mat_interp,V)

def vis_obs(initial_p,target_p,title1,title2):
    '''
        Compare two quantity plots, for example initial vs. target cellularity
        Accepts titles for each plot
    '''
    print("Plotting initial condition and target...")
    target_p = interpolate(target_p,V)
    cm1 = colors.ListedColormap([[0,1,0,1],[0,0,0,1],[1,0,0,1]])    
    cm2 = cm.get_cmap('jet')
    plt.figure()
    plt.subplot(1,2,1)
    plt.title(title1)
    plot(initial_p,cmap=cm2)
 
    plt.subplot(1,2,2)
    plt.title(title2)
    plot(target_p,cmap=cm2)
    plt.show()

def forward(initial_p,record=False):
    """ 
        Here, we define the forward problem. 
    """
    
    '''
        - E(u) returns the Green-Lagrange strain tensor
        - sigma(...) returns the actual stress tensor
        - sigma_form(...) returns the stress tensor based on the cells (phi), elasticity coefficients, and a coefficient beta
        - vonmises(...) calculates the von Mises stress based on the actual stress tensor
    '''
    print("Running the forward problem...")
    
    # Define functions
    def E(u):
        return 0.5*(nabla_grad(u) + nabla_grad(u).T)
    def sigma(u):
        I = Identity(2)             # Identity tensor
        F = I + grad(u)             # Deformation gradient
        B = F*F.T
        C = F.T*F
        J = det(F)
        I1 = tr(C)
        sigma = lmbda*(J-1)*I+mu*(B-1./2*I1*I)/(J**(5./3))
        return sigma
    def vonmises(u):
        s = sigma(u) - (1./2)*tr(sigma(u))*Identity(2)  # deviatoric stress
        von_Mises = sqrt(3./2*inner(s, s))
        return project(von_Mises, V)
    def sigma_form(u, phi):
        I = Identity(2)             # Identity tensor
        F = I + grad(u)             # Deformation gradient
        Fs = F/(1+beta*phi)
        Bs = Fs*Fs.T
        Js  = det(Fs)
        return 1/(1+beta*phi)*(mu/(Js**(5./3))*(Bs-1./2*tr(Bs)*I)+lmbda*(Js-1)*I)

   
    k.rename('k','k field')              # field of growth rate, treated as a local parameter here
    p_n = Function(V) # current distribution of cell density (phi_T)
    p_n = interpolate(initial_p,V)
    p_n.rename('phi_T','tumor fraction')
    p = TrialFunction(V)
    q = TestFunction(V)
    
    U = VectorFunctionSpace(mesh,'Lagrange',1)
    def boundary(x, on_boundary):
        return on_boundary
    bc = DirichletBC(U, Constant((0.,0.)), boundary)
    u = Function(U) 
    u.rename('u','displacement')
    v = TestFunction(U)
    F_LE = inner(sigma_form(u, p_n), E(v))*dx
    def le():
        print("Solving hyper elastic problem...")
        solve(F_LE==0, u, bc)
        return u

    disp = le()
    vm = vonmises(disp)
    D = D0*exp(-gammaD*vm)
    F_RD = (1/dt)*(p - p_n)*q*dx + D*dot(grad(q),grad(p_n))*dx - k*p_n*(1 - p_n)*q*dx  
    a_RD, L_RD = lhs(F_RD), rhs(F_RD)
    p = Function(V)
    
    # Prepare the solution
    t = 0.
    if record:        # save the current solution, k field, displacement, and diffusion
        file_results.write(p_n,t)
        file_results.write(u,t)
        file_results.write(k,t)
        D_proj = project(D,V)
        vm.rename("vm","Von Mises")
        D_proj.rename("D","diffusion coefficient")
        file_results.write(vm,t)
        file_results.write(D_proj,t)
        
    for n in range(num_steps):
        # Update current time
        t += dt
        
        # Compute solution
        print("Solving reaction diffusion for time = "+str(t))
        solve(a_RD == L_RD, p) # with trivial Neumann BC

        # Update previous solution
        p_n.assign(p)
        disp = le()
        vm   = vonmises(disp)
        D    = D0*exp(-gammaD*vm)
        
        if record:        # save the current solution, k field, displacement, and diffusion
            file_results.write(p_n,t)
            file_results.write(u,t)
            file_results.write(k,t)
            D_proj = project(D,V)
            vm.rename("vm","Von Mises")
            D_proj.rename("D","diffusion coefficient")
            file_results.write(vm,t)
            file_results.write(D_proj,t)

    return p

# Callback function for the optimizer
# Writes intermediate results to a logfile
def eval_cb(j, m):
    """ The callback function keeping a log """
    print("objective = %15.10e " % j)

def objective(p, target_p, r_coeff1, r_coeff2):
    return assemble(inner(p-target_p, p-target_p)*dx) + r_coeff1*assemble(k*k*dx) + r_coeff2*assemble(dot(grad(k),grad(k))*dx)

def optimize(dbg=False):
    """ The optimization routine """
    print("Optimizing...")
    # Define the control
    m = [Control(k), Control(D0)]
    
    # Execute first time to annotate and record the tape
    p = forward(initial_p,False)

    J = objective(p, target_p, r_coeff1, r_coeff2)

    # Prepare the reduced functional
    rf = ReducedFunctional(J,m,eval_cb_post=eval_cb)

    # upper and lower bound for the parameter field
    k_lb, k_ub = Function(V), Function(V)
    k_lb.vector()[:] = 0.
    k_ub.vector()[:] = 20.
    D_lb = Constant(0.)
    D_ub = Constant(20.)
    bnds = [[k_lb,D_lb],[k_ub,D_ub]]
    
    # Run the optimization
    m_opt = minimize(rf,method='L-BFGS-B', bounds=bnds, tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
    
    # Run the optimization
    #m_opt = minimize(rf,method='L-BFGS-B', tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
    
    return m_opt

#########################################################################
# MAIN 
#########################################################################
global D0, k, dt, theta, mu, nu, lmbda, beta, gammaD, initial_p, target_p, file_results, V, mesh, num_steps,\
    r_coeff1, r_coeff2, case, input_dir, output_dir, T
t1         = time()
case       = 0
r_coeff1   = 0.01
r_coeff2   = 0.01
input_dir  = "../rat-data/rat05/"
output_dir = './output/rat05'

# Prepare output file
file_results = XDMFFile(os.path.join(output_dir,'optimal.xdmf'))
file_results.parameters["flush_output"] = True
file_results.parameters["functions_share_mesh"] = True

# Prepare a mesh
mesh = Mesh(input_dir+"gmsh.xml")
V    = FunctionSpace(mesh, 'CG', 1)

# Model parameters
T             = 2.0             # final time 
num_steps     = 2000              # number of time steps
dt            = T/num_steps     # time step size
theta         = 50970.            # carrying capacity - normalize data by this
mu            = .42          # kPa, bulk shear modulus
nu            = .45
lmbda         = 2*mu*nu/(1-2*nu)
beta          = 1.
gammaD = Constant(1.2)    # initial guess of gamma_D

# Parameters to be optimized
D0     = Constant(1.)   # mobility or diffusion coefficient
k0     = Constant(2.)    # growth rate initial guess
k      = project(k0,V)

# Load initial tumor condition data
initial_p = interp(input_dir+"ic.mat","ic")
initial_p.rename('initial','tumor at day 0')
# target_p  = interp(input_dir+"tumor_t2.mat","tumor")  
# target_p.rename('target','tumor at day 2')

target_p = forward(initial_p, True)

D0     = Constant(2.)   # mobility or diffusion coefficient
k0     = Constant(1.5)    # growth rate initial guess
k      = project(k0,V)

# Visualize initial cellularity and target cellularity
vis_obs(initial_p,target_p,'initial','target') 

# Optimization module
[k, D0] = optimize() # optimize the k field, gammaD, and D0 using the adjoint method provided by adjoint_dolfin
model_p = forward(initial_p,False) # run the forward model using the optimized k field
print('norm(k_opt) = '+str(norm(k)))
print('J_opt = '+str(objective(model_p, target_p, r_coeff1, r_coeff2)))
print('J_opt (without regularization) = '+str(objective(model_p, target_p, 0., 0.)))
print('gamma_D = '+str(gammaD.values()[0]))
print('D0 = '+str(D0.values()[0]))
print('Elapsed time is ' + str((time()-t1)/60) + ' minutes')
vis_obs(model_p,target_p,'model','actual')
plot(k)
# Out:
# Interpolating ic...
# Running the forward problem...
# Solving hyper elastic problem...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# /home/xoab/anaconda2/lib/python2.7/site-packages/ffc/uflacs/analysis/dependencies.py:63: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   active[targets] = 1
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving reaction diffusion for time = 0.001
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.002
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.003
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.004
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.005
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.006
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.007
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.008
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.009
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.01
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.011
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.012
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.013
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.014
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.015
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.016
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.017
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.018
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.019
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.02
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.021
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.022
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.023
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.024
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.025
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.026
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.027
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.028
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.029
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.03
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.031
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.032
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.033
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.034
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.035
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.036
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.037
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.038
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.039
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.04
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.041
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.042
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.043
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.044
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.045
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.046
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.047
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.048
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.049
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.05
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.051
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.052
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.053
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.054
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.055
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.056
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.057
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.058
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.059
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.06
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.061
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.062
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.063
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.064
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.065
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.066
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.067
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.068
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.069
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.07
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.071
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.072
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.073
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.074
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.075
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.076
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.077
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.078
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.079
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.08
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.081
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.082
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.083
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.084
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.085
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.086
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.087
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.088
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.089
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.09
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.091
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.092
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.093
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.094
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.095
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.096
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.097
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.098
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.099
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.1
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.101
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.102
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.103
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.104
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.105
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.106
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.107
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.108
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.109
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.11
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.111
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.112
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.113
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.114
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.115
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.116
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.117
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.118
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.119
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.12
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.121
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.122
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.123
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.124
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.125
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.126
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.127
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.128
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.129
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.13
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.131
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.132
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.133
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.134
# Solving hyper elastic problem...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-41b83a9b6335> in <module>()
#     236 # target_p.rename('target','tumor at day 2')
#     237
# --> 238 target_p = forward(initial_p, True)
#     239
#     240 D0     = Constant(2.)   # mobility or diffusion coefficient
#
# <ipython-input-1-41b83a9b6335> in forward(initial_p, record)
#     151             D_proj.rename("D","diffusion coefficient")
#     152             file_results.write(vm,t)
# --> 153             file_results.write(D_proj,t)
#     154
#     155     return p
#
# KeyboardInterrupt:
