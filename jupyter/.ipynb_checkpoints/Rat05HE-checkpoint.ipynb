# %%
# %matplotlib inline
from __future__ import print_function
from dolfin import *
from dolfin_adjoint import *
import numpy as np
import os, sys
import scipy.io as scio
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import colors

set_log_level(ERROR) 

class InterpolatedParameter(Expression):
    '''
        Class to get tumor cell distributions by interpolating based off matrices of tumor cell data
    '''
    def __init__(self,X,Y,image,**kwargs):
        self.X = X # A numpy array giving the X-spacing of the image
        self.Y = Y # Same for Y
        self.image = image # The image of measured material property    
    def eval_cell(self,values,x,cell):
        interp_handle = RegularGridInterpolator((self.X,self.Y),self.image)
        values[0] = interp_handle(x)
        
def interp(file_loc,mat_name):
    print("Interpolating "+mat_name+"...")
    mat = scio.loadmat(file_loc)[mat_name]
    mat = np.fliplr(mat.T)/theta  # Needs to be adjusted to fit the mesh correctly; also scaled
    x,y = mat.shape[0], mat.shape[1]
    mat_interp = InterpolatedParameter(np.linspace(1,x,x),np.linspace(1,y,y),mat,degree=1)
    return interpolate(mat_interp,V)

def vis_obs(initial_p,target_p,title1,title2):
    '''
        Compare two quantity plots, for example initial vs. target cellularity
        Accepts titles for each plot
    '''
    print("Plotting initial condition and target...")
    target_p = interpolate(target_p,V)
    cm1 = colors.ListedColormap([[0,1,0,1],[0,0,0,1],[1,0,0,1]])    
    cm2 = cm.get_cmap('jet')
    plt.figure()
    plt.subplot(1,2,1)
    plt.title(title1)
    plot(initial_p,cmap=cm2)
 
    plt.subplot(1,2,2)
    plt.title(title2)
    plot(target_p,cmap=cm2)
    plt.show()

def forward(initial_p,record=False):
    """ 
        Here, we define the forward problem. 
    """
    
    '''
        - E(u) returns the Green-Lagrange strain tensor
        - sigma(...) returns the actual stress tensor
        - sigma_form(...) returns the stress tensor based on the cells (phi), elasticity coefficients, and a coefficient beta
        - vonmises(...) calculates the von Mises stress based on the actual stress tensor
    '''
    print("Running the forward problem...")
    
    # Define functions
    def E(u):
        return 0.5*(nabla_grad(u) + nabla_grad(u).T)
    def sigma(u):
        I = Identity(2)             # Identity tensor
        F = I + grad(u)             # Deformation gradient
        B = F*F.T
        C = F.T*F
        J = det(F)
        I1 = tr(C)
        sigma = lmbda*(J-1)*I+mu*(B-1./2*I1*I)/(J**(5./3))
        return sigma
    def vonmises(u):
        s = sigma(u) - (1./2)*tr(sigma(u))*Identity(2)  # deviatoric stress
        von_Mises = sqrt(3./2*inner(s, s))
        return project(von_Mises, V)
    def sigma_form(u, phi):
        I = Identity(2)             # Identity tensor
        F = I + grad(u)             # Deformation gradient
        Fs = F/(1+beta*phi)
        Bs = Fs*Fs.T
        Js  = det(Fs)
        return 1/(1+beta*phi)*(mu/(Js**(5./3))*(Bs-1./2*tr(Bs)*I)+lmbda*(Js-1)*I)

   
    k.rename('k','k field')              # field of growth rate, treated as a local parameter here
    p_n = Function(V) # current distribution of cell density (phi_T)
    p_n = interpolate(initial_p,V)
    p_n.rename('phi_T','tumor fraction')
    p = Function(V)
    q = TestFunction(V)
    
    U = VectorFunctionSpace(mesh,'Lagrange',1)
    def boundary(x, on_boundary):
        return on_boundary
    bc = DirichletBC(U, Constant((0.,0.)), boundary)
    u = Function(U) 
    u.rename('u','displacement')
    v = TestFunction(U)
    F_LE = inner(sigma_form(u, p_n), E(v))*dx
    def le():
        print("Solving hyper elastic problem...")
        solve(F_LE==0, u, bc)
        return u

    disp = le()
    vm = vonmises(disp)
    D = D0*exp(-gammaD*vm)
    F_RD = (1/dt)*(p - p_n)*q*dx + D*dot(grad(q),grad(p))*dx - k*p*(1 - p)*q*dx  

    # Prepare the solution
    t = 0.
    if record:        # save the current solution, k field, displacement, and diffusion
        file_results.write(p_n,t)
        file_results.write(u,t)
        file_results.write(k,t)
        D_proj = project(D,V)
        vm.rename("vm","Von Mises")
        D_proj.rename("D","diffusion coefficient")
        file_results.write(vm,t)
        file_results.write(D_proj,t)
        
    for n in range(num_steps):
        # Update current time
        t += dt
        
        # Compute solution
        print("Solving reaction diffusion for time = "+str(t))
        solve(F_RD == 0, p) # with trivial Neumann BC

        # Update previous solution
        p_n.assign(p)
        disp = le()
        vm   = vonmises(disp)
        D    = D0*exp(-gammaD*vm)
        
        if record:        # save the current solution, k field, displacement, and diffusion
            file_results.write(p_n,t)
            file_results.write(u,t)
            file_results.write(k,t)
            D_proj = project(D,V)
            D_proj.rename("D","diffusion coefficient")
            file_results.write(vm,t)
            file_results.write(D_proj,t)

    return p

# Callback function for the optimizer
# Writes intermediate results to a logfile
def eval_cb(j, m):
    """ The callback function keeping a log """
    print("objective = %15.10e " % j)

def objective(p, target_p, r_coeff1, r_coeff2):
    return assemble(inner(p-target_p, p-target_p)*dx) + r_coeff1*assemble(k*k*dx) + r_coeff2*assemble(dot(grad(k),grad(k))*dx)

def optimize(dbg=False):
    """ The optimization routine """
    print("Optimizing...")
    # Define the control
    m = [Control(k), Control(D0)]
    
    # Execute first time to annotate and record the tape
    p = forward(initial_p,False)

    J = objective(p, target_p, r_coeff1, r_coeff2)

    # Prepare the reduced functional
    rf = ReducedFunctional(J,m,eval_cb_post=eval_cb)

    # upper and lower bound for the parameter field
    k_lb, k_ub = Function(V), Function(V)
    k_lb.vector()[:] = 0.
    k_ub.vector()[:] = 20.
    D_lb = Constant(0.)
    D_ub = Constant(20.)
    bnds = [[k_lb,D_lb],[k_ub,D_ub]]
    
    # Run the optimization
    m_opt = minimize(rf,method='L-BFGS-B', bounds=bnds, tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
    
    # Run the optimization
    #m_opt = minimize(rf,method='L-BFGS-B', tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
    
    return m_opt

#########################################################################
# MAIN 
#########################################################################
def main():
    global D0, k, dt, theta, mu, nu, lmbda, beta, gammaD, initial_p, target_p, file_results, V, mesh, num_steps,\
        r_coeff1, r_coeff2, case, input_dir, output_dir, T
    t1         = time()
    case       = 0
    r_coeff1   = 0.01
    r_coeff2   = 0.01
    input_dir  = "../rat-data/rat05/"
    output_dir = './output/rat05'

    # Prepare output file
    file_results = XDMFFile(os.path.join(output_dir,'optimal.xdmf'))
    file_results.parameters["flush_output"] = True
    file_results.parameters["functions_share_mesh"] = True

    # Prepare a mesh
    mesh = Mesh(input_dir+"gmsh.xml")
    V    = FunctionSpace(mesh, 'CG', 1)

    # Model parameters
    T             = .10             # final time 
    num_steps     = 10              # number of time steps
    dt            = T/num_steps     # time step size
    theta         = 50970.            # carrying capacity - normalize data by this
    mu            = .42          # kPa, bulk shear modulus
    nu            = .45
    lmbda         = 2*mu*nu/(1-2*nu)
    beta          = 1.
    gammaD = Constant(1.2)    # initial guess of gamma_D

    # Parameters to be optimized
    D0     = Constant(10.)   # mobility or diffusion coefficient
    k0     = Constant(2.)    # growth rate initial guess
    k      = project(k0,V)

    # Load initial tumor condition data
    initial_p = interp(input_dir+"ic.mat","ic")
    initial_p.rename('initial','tumor at day 0')
    # target_p  = interp(input_dir+"tumor_t2.mat","tumor")  
    # target_p.rename('target','tumor at day 2')

    target_p = forward(initial_p, True)

    D0     = Constant(8.)   # mobility or diffusion coefficient
    k0     = Constant(8.)    # growth rate initial guess
    k      = project(k0,V)

    # Visualize initial cellularity and target cellularity
    vis_obs(initial_p,target_p,'initial','target') 

    # Optimization module
    [k, D0] = optimize() # optimize the k field, gammaD, and D0 using the adjoint method provided by adjoint_dolfin
    model_p = forward(initial_p,False) # run the forward model using the optimized k field
    print('norm(k_opt) = '+str(norm(k)))
    print('J_opt = '+str(objective(model_p, target_p, r_coeff1, r_coeff2)))
    print('J_opt (without regularization) = '+str(objective(model_p, target_p, 0., 0.)))
    print('gamma_D = '+str(gammaD.values()[0]))
    print('D0 = '+str(D0.values()[0]))
    print('Elapsed time is ' + str((time()-t1)/60) + ' minutes')
    vis_obs(model_p,target_p,'model','actual')
    plot(k)

import profile
profile.run('main()')
# Out:
# Interpolating ic...
# Running the forward problem...
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.01
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.02
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.03
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.04
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.05
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.06
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.07
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.08
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.09
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.1
# Solving hyper elastic problem...
# Plotting initial condition and target...
# Optimizing...
# Running the forward problem...
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.01
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.02
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.03
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.04
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.05
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.06
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.07
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.08
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.09
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.1
# Solving hyper elastic problem...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#   WARNING: The number of integration points for each cell will be: 100
#            Consider using the option 'quadrature_degree' to reduce the number of points
# Running the forward problem...
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.01
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.02
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.03
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.04
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.05
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.06
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.07
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.08
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.09
# Solving hyper elastic problem...
# Solving reaction diffusion for time = 0.1
# Solving hyper elastic problem...
# norm(k_opt) = 0.791995044915
# J_opt = 0.204137716986
# J_opt (without regularization) = 0.197367076236
# gamma_D = 1.2
# D0 = 7.11825632821
# Elapsed time is 206.497980346 minutes
# Plotting initial condition and target...
#          142647096 function calls (139005237 primitive calls) in 11751.704 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      5218  348.490    0.067  348.490    0.067 :0(Assembler_assemble)
#      5218    0.010    0.000    0.010    0.000 :0(Assembler_swiginit)
#     21153    0.059    0.000    0.059    0.000 :0(CellType_description)
#       302    0.001    0.000    0.001    0.000 :0(Constant_swiginit)
#         5    0.000    0.000    0.000    0.000 :0(Constant_values)
#       124    0.000    0.000    0.000    0.000 :0(DirichletBC__function_space)
#       124    1.300    0.010    4.118    0.033 :0(DirichletBC_apply)
#        62    0.000    0.000    0.000    0.000 :0(DirichletBC_homogenize)
#      2139    0.008    0.000    0.008    0.000 :0(DirichletBC_set_value)
#       127    0.000    0.000    0.000    0.000 :0(DirichletBC_swiginit)
#      1306    0.003    0.000    0.003    0.000 :0(DofMap_swiginit)
#        34    0.000    0.000    0.000    0.000 :0(DoubleArray_swiginit)
#        34    0.000    0.000    0.000    0.000 :0(Expression_eval)
#         1    0.000    0.000    0.000    0.000 :0(Expression_swiginit)
#       372    0.001    0.000    0.001    0.000 :0(FiniteElement_num_sub_elements)
#     19794    0.071    0.000    0.071    0.000 :0(FiniteElement_signature)
#      1306    0.002    0.000    0.002    0.000 :0(FiniteElement_swiginit)
#      5310    0.023    0.000    0.023    0.000 :0(Form_mesh)
#     30712    0.080    0.000    0.080    0.000 :0(Form_num_coefficients)
#     42269    0.103    0.000    0.103    0.000 :0(Form_original_coefficient_position)
#     10528    0.025    0.000    0.025    0.000 :0(Form_rank)
#     42269    0.138    0.000    0.138    0.000 :0(Form_set_coefficient)
#     15356    0.047    0.000    0.047    0.000 :0(Form_set_mesh)
#     15356    0.027    0.000    0.027    0.000 :0(Form_swiginit)
#        62    0.000    0.000    0.000    0.000 :0(FunctionSpace_component)
#       248    0.000    0.000    0.000    0.000 :0(FunctionSpace_dim)
#     20166    0.057    0.000    0.057    0.000 :0(FunctionSpace_element)
#     19916    0.064    0.000    0.064    0.000 :0(FunctionSpace_mesh)
#      1306    0.003    0.000    0.003    0.000 :0(FunctionSpace_swiginit)
#      3936    0.105    0.000    0.105    0.000 :0(Function__assign)
#         5    0.011    0.002    0.011    0.002 :0(Function_compute_vertex_values)
#         6    0.267    0.045   29.960    4.993 :0(Function_interpolate)
#     14575    0.028    0.000    0.028    0.000 :0(Function_swiginit)
#      5685    0.020    0.000    0.020    0.000 :0(Function_vector)
#     19546    0.092    0.000    0.092    0.000 :0(GenericFunction__function_space)
#         5    0.000    0.000    0.000    0.000 :0(GenericFunction_value_rank)
#       194    0.001    0.000    0.001    0.000 :0(GenericFunction_value_size)
#        63    0.001    0.000    0.001    0.000 :0(GenericTensor_apply)
#         2    0.000    0.000    0.000    0.000 :0(GenericVector__assign)
#       124    0.001    0.000    0.001    0.000 :0(GenericVector__scale)
#      3193    0.030    0.000    0.030    0.000 :0(GenericVector_axpy)
#      7943    0.223    0.000    0.223    0.000 :0(GenericVector_copy)
#        68    0.003    0.000    0.003    0.000 :0(GenericVector_gather)
#        63    0.000    0.000    0.000    0.000 :0(GenericVector_local_range)
#        31    0.000    0.000    0.000    0.000 :0(GenericVector_local_size)
#        63    0.002    0.000    0.002    0.000 :0(GenericVector_set_local)
#       265    0.001    0.000    0.001    0.000 :0(GenericVector_size)
#       124    0.002    0.000    0.002    0.000 :0(GenericVector_sum)
#      2294    0.004    0.000    0.004    0.000 :0(LinearVariationalProblem_swiginit)
#      2294  105.164    0.046  105.164    0.046 :0(LinearVariationalSolver_solve)
#      2294    0.004    0.000    0.004    0.000 :0(LinearVariationalSolver_swiginit)
#     16662    0.049    0.000    0.049    0.000 :0(MPI_size)
#       852    0.002    0.000    0.002    0.000 :0(Matrix_swiginit)
#     19842    0.036    0.000    0.036    0.000 :0(MeshGeometry_degree)
#     21163    0.044    0.000    0.044    0.000 :0(MeshGeometry_dim)
#         5    0.000    0.000    0.000    0.000 :0(MeshTopology_dim)
#         5    0.000    0.000    0.000    0.000 :0(Mesh__cells)
#         5    0.000    0.000    0.000    0.000 :0(Mesh__coordinates)
#     41005    0.120    0.000    0.120    0.000 :0(Mesh_geometry)
#     22037    0.098    0.000    0.098    0.000 :0(Mesh_mpi_comm)
#         5    0.000    0.000    0.000    0.000 :0(Mesh_num_cells)
#         1    0.000    0.000    0.000    0.000 :0(Mesh_swiginit)
#         5    0.000    0.000    0.000    0.000 :0(Mesh_topology)
#     21153    0.050    0.000    0.050    0.000 :0(Mesh_type)
#      2729    0.005    0.000    0.005    0.000 :0(NonlinearVariationalProblem_swiginit)
#      2729 10666.815    3.909 10666.963    3.909 :0(NonlinearVariationalSolver_solve)
#      2729    0.005    0.000    0.005    0.000 :0(NonlinearVariationalSolver_swiginit)
#    299916    0.487    0.000    0.487    0.000 :0(ParameterValue___nonzero__)
#    216606    0.569    0.000    0.569    0.000 :0(ParameterValue__assign)
#    149960    0.285    0.000    0.285    0.000 :0(ParameterValue__assign_bool)
#    833100    1.390    0.000    1.390    0.000 :0(ParameterValue_is_set)
#     99972    0.172    0.000    0.172    0.000 :0(ParameterValue_reset)
#    733128    1.280    0.000    1.280    0.000 :0(ParameterValue_type_str)
#    266592    0.825    0.000    0.825    0.000 :0(Parameters__add)
#    149958    0.402    0.000    0.402    0.000 :0(Parameters__add_bool)
#   1299638    3.020    0.000    3.020    0.000 :0(Parameters__get_parameter)
#   1366286    5.577    0.000    5.577    0.000 :0(Parameters__get_parameter_keys)
#     16662    0.048    0.000    0.048    0.000 :0(Parameters__get_parameter_set)
#     66648    0.148    0.000    0.148    0.000 :0(Parameters__get_parameter_set_keys)
#    416550    0.934    0.000    0.934    0.000 :0(Parameters_has_parameter_set)
#     16662    0.032    0.000    0.032    0.000 :0(Parameters_swiginit)
#       196    0.000    0.000    0.000    0.000 :0(Scalar_get_scalar_value)
#       196    0.000    0.000    0.000    0.000 :0(Scalar_swiginit)
#         3    0.000    0.000    0.000    0.000 :0(SubDomain_swiginit)
#        46    0.778    0.017    0.778    0.017 :0(SystemAssembler_assemble)
#        46    0.000    0.000    0.000    0.000 :0(SystemAssembler_swiginit)
#     54562    0.138    0.000    0.138    0.000 :0(Variable_id)
#       134    0.000    0.000    0.000    0.000 :0(Variable_name)
#     14900    0.054    0.000    0.054    0.000 :0(Variable_rename)
#        93    0.000    0.000    0.000    0.000 :0(Vector_get_local)
#      4262    0.009    0.000    0.009    0.000 :0(Vector_swiginit)
#         4    0.000    0.000    0.000    0.000 :0(WEXITSTATUS)
#         4    0.000    0.000    0.000    0.000 :0(WIFEXITED)
#         4    0.000    0.000    0.000    0.000 :0(WIFSIGNALED)
#         1    0.000    0.000    0.000    0.000 :0(XDMFFile_swiginit)
#        55    0.188    0.003    0.188    0.003 :0(XDMFFile_write)
#        26    0.000    0.000    0.000    0.000 :0(__array_prepare__)
#        35    0.000    0.000    0.000    0.000 :0(__contains__)
#         1    0.000    0.000    0.000    0.000 :0(__debug)
#        10    0.000    0.000    0.000    0.000 :0(__enter__)
#        10    0.000    0.000    0.000    0.000 :0(__exit__)
#        27    0.001    0.000    0.001    0.000 :0(__import__)
#    575904    1.218    0.000    1.218    0.000 :0(__new__)
#         5    0.000    0.000    0.000    0.000 :0(__reduce_ex__)
#         8    0.000    0.000    0.000    0.000 :0(__subclasses__)
#         7    0.000    0.000    0.000    0.000 :0(__subclasshook__)
#        10    0.000    0.000    0.000    0.000 :0(_attach_base_to_numpy_array)
#      4346    0.007    0.000    0.007    0.000 :0(_getframe)
#      6386    0.021    0.000    0.021    0.000 :0(_has_type_PETScVector)
#      5458    0.023    0.000    0.023    0.000 :0(_info)
#     58881    0.307    0.000    0.591    0.000 :0(_ndim_coords_from_arrays)
#     12586    0.022    0.000    0.023    0.000 :0(abs)
#        10    0.000    0.000    0.000    0.000 :0(accumulate)
#      4378    0.012    0.000    0.012    0.000 :0(acquire)
#   3869220   14.724    0.000   23.965    0.000 :0(add)
#         8    0.000    0.000    0.000    0.000 :0(add_docstring)
#       986    0.002    0.000    0.002    0.000 :0(affine_transform)
# 2006750/1998567    9.852    0.000   24.203    0.000 :0(all)
#        25    0.000    0.000    0.000    0.000 :0(allocate_lock)
#    214084    1.782    0.000   16.276    0.000 :0(any)
#   4309303    7.000    0.000    7.000    0.000 :0(append)
#       112    0.001    0.000    0.001    0.000 :0(arange)
# 1150301/1150270    2.031    0.000    2.041    0.000 :0(array)
#         1    0.000    0.000    0.000    0.000 :0(array_from_header)
#        45    0.000    0.000    0.000    0.000 :0(astype)
#       283    0.001    0.000    0.001    0.000 :0(b2a_base64)
#        19    0.000    0.000    0.000    0.000 :0(bisect)
#      1042    0.002    0.000    0.002    0.000 :0(callable)
#     58881    0.141    0.000    0.141    0.000 :0(can_cast)
#        12    0.001    0.000    0.001    0.000 :0(chmod)
#         4    0.000    0.000    0.000    0.000 :0(chr)
#       326    0.001    0.000    0.001    0.000 :0(clear)
#        13    0.000    0.000    0.000    0.000 :0(clip)
#         8    0.000    0.000    0.000    0.000 :0(cloexec_pipe)
#        22    0.000    0.000    0.000    0.000 :0(close)
#         2    0.002    0.001    0.002    0.001 :0(collect)
#        30    0.001    0.000    0.001    0.000 :0(compile)
#         9    0.003    0.000    0.003    0.000 :0(compress)
#         4    0.000    0.000    0.000    0.000 :0(compressobj)
#        48    0.000    0.000    0.000    0.000 :0(concatenate)
#    121433    0.271    0.000    0.271    0.000 :0(copy)
#        49    0.000    0.000    0.000    0.000 :0(copyto)
#       208    0.000    0.000    0.000    0.000 :0(cos)
#       466    0.001    0.000    0.001    0.000 :0(count)
#        18    0.000    0.000    0.000    0.000 :0(count_nonzero)
#        13    0.000    0.000    0.000    0.000 :0(crc32)
#       188    0.163    0.001    0.163    0.001 :0(create_filled_contour)
#        33    0.000    0.000    0.000    0.000 :0(cumsum)
#   1083995    3.721    0.000    9.315    0.000 :0(decode)
#        32    0.000    0.000    0.000    0.000 :0(difference)
#         2    0.000    0.000    0.000    0.000 :0(digest)
#        16    0.000    0.000    0.000    0.000 :0(dir)
#   152/137    0.000    0.000    0.001    0.000 :0(divmod)
#        29    0.036    0.001    0.036    0.001 :0(dlopen)
#      5139    0.015    0.000    0.015    0.000 :0(dot)
#       136    0.001    0.000    0.001    0.000 :0(draw_glyphs_to_bitmap)
#       256    0.010    0.000    0.017    0.000 :0(draw_markers)
#        44    0.002    0.000    0.002    0.000 :0(draw_path)
#       306    0.019    0.000    0.081    0.000 :0(draw_path_collection)
#       136    0.005    0.000    0.006    0.000 :0(draw_text_image)
#         2    0.000    0.000    0.000    0.000 :0(einsum)
#      3541    0.009    0.000    0.009    0.000 :0(empty)
#     16768    0.113    0.000    0.114    0.000 :0(encode)
#    467115    0.983    0.000    0.983    0.000 :0(endswith)
#     19821    0.641    0.000    6.786    0.000 :0(eval)
#         1    0.000    0.000    0.000    0.000 :0(exc_info)
#         9    0.000    0.000    0.000    0.000 :0(expandtabs)
#     47082    0.089    0.000    0.089    0.000 :0(extend)
#       415    0.001    0.000    0.001    0.000 :0(fabs)
#         8    0.000    0.000    0.000    0.000 :0(factorial)
#         4    0.000    0.000    0.000    0.000 :0(fdopen)
#       217    0.004    0.000    0.007    0.000 :0(filter)
#      4346    0.008    0.000    0.008    0.000 :0(find)
#        12    0.000    0.000    0.000    0.000 :0(findall)
#       223    0.001    0.000    0.001    0.000 :0(flatten)
#        96    0.000    0.000    0.000    0.000 :0(floor)
#      4322    0.011    0.000    0.011    0.000 :0(flush)
#         4    0.013    0.003    0.013    0.003 :0(fork_exec)
#     27115    0.083    0.000    0.083    0.000 :0(format)
#        15    0.000    0.000    0.000    0.000 :0(frexp)
#        24    0.000    0.000    0.000    0.000 :0(gamma)
# 5338716/5338714   18.194    0.000   50.440    0.000 :0(get)
#       136    0.000    0.000    0.000    0.000 :0(get_bitmap_offset)
#       280    0.001    0.000    0.001    0.000 :0(get_descent)
#     25993    0.045    0.000    0.045    0.000 :0(get_ident)
#       153    0.003    0.000    0.006    0.000 :0(get_path_collection_extents)
#        44    0.001    0.000    0.003    0.000 :0(get_path_extents)
#       144    0.000    0.000    0.000    0.000 :0(get_width_height)
#   8216805   17.593    0.000   17.623    0.000 :0(getattr)
#         1    0.000    0.000    0.000    0.000 :0(getcwd)
#         1    0.000    0.000    0.000    0.000 :0(getdefaultencoding)
#      2632    0.005    0.000    0.005    0.000 :0(geterrobj)
#         4    0.000    0.000    0.000    0.000 :0(getfilesystemencoding)
#      4483    0.009    0.000    0.009    0.000 :0(getpid)
#         4    0.000    0.000    0.000    0.000 :0(getvalue)
#        15    0.000    0.000    0.000    0.000 :0(globals)
#       296    0.000    0.000    0.000    0.000 :0(group)
#    333975    0.675    0.000    0.675    0.000 :0(hasattr)
# 2966139/2460308    7.985    0.000   16.733    0.000 :0(hash)
#     31995    0.097    0.000    0.097    0.000 :0(hexdigest)
#         1    0.000    0.000    0.000    0.000 :0(hexlify)
#   2906574    5.235    0.000    5.235    0.000 :0(id)
#     36891    0.076    0.000    0.080    0.000 :0(index)
#       141    0.000    0.000    0.000    0.000 :0(insert)
#         4    0.000    0.000    0.000    0.000 :0(intersection)
#  15490558   30.330    0.000   36.024    0.000 :0(isinstance)
#         2    0.000    0.000    0.000    0.000 :0(isoformat)
# 162828/162815    0.309    0.000    0.309    0.000 :0(issubclass)
#       713    0.002    0.000    0.002    0.000 :0(issuperset)
#        13    0.000    0.000    0.000    0.000 :0(item)
#    119282    0.307    0.000    0.307    0.000 :0(items)
#    426388    0.698    0.000    0.698    0.000 :0(iter)
#    114420    0.193    0.000    0.193    0.000 :0(iteritems)
#     21687    0.037    0.000    0.037    0.000 :0(iterkeys)
#      4670    0.008    0.000    0.008    0.000 :0(itervalues)
#     23429    0.063    0.000    0.118    0.000 :0(join)
#     85672    0.199    0.000    0.199    0.000 :0(keys)
#       852   28.818    0.034   28.818    0.034 :0(la_solve)
#        10    0.000    0.000    0.000    0.000 :0(ldexp)
# 4841719/4690868    9.218    0.000    9.709    0.000 :0(len)
#        28    0.006    0.000    0.014    0.001 :0(listdir)
#         2    0.000    0.000    0.000    0.000 :0(locals)
#        36    0.000    0.000    0.000    0.000 :0(log)
#       135    0.000    0.000    0.000    0.000 :0(log10)
#     59373    0.114    0.000    0.114    0.000 :0(lower)
#      1306    0.004    0.000    0.004    0.000 :0(make_ufc_dofmap)
#      1306    0.008    0.000    0.008    0.000 :0(make_ufc_finite_element)
#     15356    0.099    0.000    0.099    0.000 :0(make_ufc_form)
#       506    0.003    0.000    0.007    0.000 :0(map)
#      1348    0.003    0.000    0.003    0.000 :0(match)
#     26240    0.057    0.000    0.060    0.000 :0(max)
#      3274    0.009    0.000    0.010    0.000 :0(min)
#        24    0.001    0.000    0.001    0.000 :0(mkdir)
#      2380    0.005    0.000    0.005    0.000 :0(mro)
#      5218    0.010    0.000    0.010    0.000 :0(new_Assembler)
#       302    0.001    0.000    0.001    0.000 :0(new_Constant)
#       127    0.002    0.000    0.002    0.000 :0(new_DirichletBC)
#      1306    3.750    0.003    3.750    0.003 :0(new_DofMap)
#        34    0.000    0.000    0.000    0.000 :0(new_DoubleArray)
#         1    0.000    0.000    0.000    0.000 :0(new_Expression)
#      1306    0.004    0.000    0.004    0.000 :0(new_FiniteElement)
#     15356    0.079    0.000    0.079    0.000 :0(new_Form)
#     14575    2.366    0.000    2.366    0.000 :0(new_Function)
#      1306    0.008    0.000    0.008    0.000 :0(new_FunctionSpace)
#      2294    0.014    0.000    0.014    0.000 :0(new_LinearVariationalProblem)
#      2294    0.071    0.000    0.071    0.000 :0(new_LinearVariationalSolver)
#       852    0.016    0.000    0.016    0.000 :0(new_Matrix)
#         1    0.010    0.010    0.010    0.010 :0(new_Mesh)
#      2729    0.014    0.000    0.014    0.000 :0(new_NonlinearVariationalProblem)
#      2729    0.278    0.000    0.278    0.000 :0(new_NonlinearVariationalSolver)
#     16662    0.095    0.000    0.095    0.000 :0(new_Parameters)
#       196    0.002    0.000    0.002    0.000 :0(new_Scalar)
#         3    0.000    0.000    0.000    0.000 :0(new_SubDomain)
#        46    0.000    0.000    0.000    0.000 :0(new_SystemAssembler)
#      4262    0.082    0.000    0.082    0.000 :0(new_Vector)
#         1    0.000    0.000    0.000    0.000 :0(new_XDMFFile)
#       224    0.000    0.000    0.001    0.000 :0(next)
#         2    0.000    0.000    0.000    0.000 :0(now)
#        47    0.002    0.000    0.002    0.000 :0(open)
#     16694    0.075    0.000    0.075    0.000 :0(openssl_sha1)
#     15299    0.187    0.000    0.187    0.000 :0(openssl_sha512)
#      1253    0.004    0.000    0.004    0.000 :0(ord)
#        12    0.000    0.000    0.000    0.000 :0(pack)
#        76    0.000    0.000    0.000    0.000 :0(partition)
#    572804    1.081    0.000    1.081    0.000 :0(pop)
#         8    0.000    0.000    0.000    0.000 :0(pow)
#        76    0.001    0.000    0.014    0.000 :0(print)
#        24    0.000    0.000    0.000    0.000 :0(ptp)
#       272    0.001    0.000    0.001    0.000 :0(radians)
#      6282    0.010    0.000    0.010    0.000 :0(random)
#     49144    0.115    0.000    0.115    0.000 :0(range)
#       811    0.002    0.000    0.002    0.000 :0(ravel)
#        59    0.001    0.000    0.001    0.000 :0(read)
#         2    0.000    0.000    0.000    0.000 :0(read_full_tag)
#         1    0.000    0.000    0.000    0.000 :0(read_header)
#    431643    1.720    0.000    1.896    0.000 :0(reduce)
#      4348    0.007    0.000    0.007    0.000 :0(release)
#      4341    0.007    0.000    0.007    0.000 :0(remove)
#        84    0.003    0.000    0.003    0.000 :0(rename)
#       525    0.001    0.000    0.001    0.000 :0(replace)
# 1405792/1217728    4.405    0.000    8.591    0.000 :0(repr)
#    119468    0.294    0.000    0.294    0.000 :0(reshape)
#       639    0.002    0.000    0.002    0.000 :0(result_type)
#        79    0.000    0.000    0.000    0.000 :0(reverse)
#     13042    0.026    0.000    0.026    0.000 :0(rfind)
#       405    0.001    0.000    0.001    0.000 :0(round)
#        23    0.000    0.000    0.000    0.000 :0(rpartition)
#        86    0.000    0.000    0.000    0.000 :0(rstrip)
#        84    0.000    0.000    0.000    0.000 :0(search)
#    117765    0.346    0.000    0.346    0.000 :0(searchsorted)
#         1    0.000    0.000    0.000    0.000 :0(seed)
#         9    0.000    0.000    0.000    0.000 :0(seek)
#       280    0.001    0.000    0.001    0.000 :0(set_size)
#         1    0.000    0.000    0.000    0.000 :0(set_stream)
#       280    0.007    0.000    0.007    0.000 :0(set_text)
#       164    0.000    0.000    0.000    0.000 :0(setattr)
#       361    0.001    0.000    0.001    0.000 :0(setdefault)
#      1316    0.003    0.000    0.003    0.000 :0(seterrobj)
#         1    0.000    0.000    0.000    0.000 :0(setprofile)
#       136    0.000    0.000    0.000    0.000 :0(sin)
#        62    0.000    0.000    0.000    0.000 :0(sizeof_la_index)
#       140    0.001    0.000    0.002    0.000 :0(sort)
# 647120/647086    3.959    0.000   11.452    0.000 :0(sorted)
#     72983    0.142    0.000    0.142    0.000 :0(split)
#         7    0.000    0.000    0.000    0.000 :0(splitlines)
#       148    0.000    0.000    0.000    0.000 :0(sqrt)
#      7818    0.013    0.000    0.013    0.000 :0(startswith)
#       417    0.010    0.000    0.010    0.000 :0(stat)
#       689    0.002    0.000    0.002    0.000 :0(strip)
#      3924    0.021    0.000    0.058    0.000 :0(sub)
#     51712    0.392    0.000    1.461    0.000 :0(sum)
#        20    0.000    0.000    0.000    0.000 :0(take)
#         3    0.000    0.000    0.000    0.000 :0(tell)
#      4380    0.010    0.000    0.010    0.000 :0(time)
#        72    0.004    0.000    0.004    0.000 :0(tolist)
#        60    0.000    0.000    0.000    0.000 :0(tostring)
#        12    0.000    0.000    0.000    0.000 :0(translate)
#       157    0.000    0.000    0.000    0.000 :0(transpose)
#         1    0.000    0.000    0.000    0.000 :0(unichr)
#        13    0.000    0.000    0.000    0.000 :0(unlink)
#    148394    1.172    0.000   11.601    0.000 :0(update)
#         5    0.000    0.000    0.000    0.000 :0(update_path_extents)
#        38    0.000    0.000    0.000    0.000 :0(upper)
#        47    0.000    0.000    0.000    0.000 :0(urandom)
#   1085332    2.134    0.000    2.134    0.000 :0(utf_8_decode)
#        12    0.001    0.000    0.001    0.000 :0(utime)
#     86570    0.189    0.000    0.189    0.000 :0(values)
#         7    0.000    0.000    0.000    0.000 :0(vars)
#        20    0.000    0.000    0.002    0.000 :0(view)
#         4    0.000    0.000    0.000    0.000 :0(waitpid)
#    471188    1.275    0.000    1.275    0.000 :0(where)
#      4619    0.068    0.000    0.068    0.000 :0(write)
#         4    0.016    0.004    0.016    0.004 :0(write_png)
#     61872    0.204    0.000    0.204    0.000 :0(zeros)
#   1254472    2.855    0.000    2.873    0.000 :0(zip)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-10>:1(<module>)
#         2    0.000    0.000    0.001    0.001 <decorator-gen-10>:1(__call__)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-11>:1(<module>)
#         2    0.000    0.000    0.000    0.000 <decorator-gen-11>:1(__call__)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-5>:1(<module>)
#         6    0.000    0.000    0.005    0.001 <decorator-gen-5>:1(non_reentrant)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-6>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-7>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-8>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-9>:1(<module>)
#        18    0.000    0.000    1.597    0.089 <decorator-gen-9>:1(__call__)
#    561210    0.939    0.000    0.939    0.000 <ipython-input-2-f1be41b895e6>:100(boundary)
#        33    0.000    0.000  232.504    7.046 <ipython-input-2-f1be41b895e6>:107(le)
#         3    0.000    0.000    0.169    0.056 <ipython-input-2-f1be41b895e6>:160(objective)
#         1    0.000    0.000 11555.822 11555.822 <ipython-input-2-f1be41b895e6>:163(optimize)
#         1    0.000    0.000    0.000    0.000 <ipython-input-2-f1be41b895e6>:19(__init__)
#         1    0.000    0.000 11751.704 11751.704 <ipython-input-2-f1be41b895e6>:196(main)
#     58881    0.484    0.000   29.693    0.001 <ipython-input-2-f1be41b895e6>:23(eval_cell)
#         1    0.000    0.000   29.948   29.948 <ipython-input-2-f1be41b895e6>:27(interp)
#         2    0.000    0.000    2.834    1.417 <ipython-input-2-f1be41b895e6>:35(vis_obs)
#         3    0.002    0.001  243.611   81.204 <ipython-input-2-f1be41b895e6>:54(forward)
#         3    0.000    0.000    0.005    0.002 <ipython-input-2-f1be41b895e6>:68(E)
#        66    0.004    0.000    0.626    0.009 <ipython-input-2-f1be41b895e6>:70(sigma)
#        33    0.001    0.000    4.181    0.127 <ipython-input-2-f1be41b895e6>:79(vonmises)
#         3    0.000    0.000    0.026    0.009 <ipython-input-2-f1be41b895e6>:83(sigma_form)
#     33559    0.142    0.000    0.494    0.000 <string>:1(<lambda>)
#   19919/1    0.246    0.000 11751.704 11751.704 <string>:1(<module>)
#         7    0.000    0.000    0.000    0.000 <string>:2(<module>)
#      4896    0.016    0.000    0.024    0.000 <string>:8(__new__)
#    100052    0.194    0.000    0.194    0.000 UserDict.py:103(__contains__)
#     66700    0.134    0.000    0.134    0.000 UserDict.py:35(__getitem__)
#     13825    0.110    0.000    0.156    0.000 UserDict.py:4(__init__)
#    100052    0.531    0.000    0.860    0.000 UserDict.py:91(get)
#         2    0.003    0.002    0.020    0.010 __init__.py:1(<module>)
#         1    0.004    0.004    0.028    0.028 __init__.py:108(<module>)
#     16711    0.069    0.000    0.184    0.000 __init__.py:1137(debug)
#         2    0.000    0.000    0.002    0.001 __init__.py:1161(warning)
#      4316    0.046    0.000    1.328    0.000 __init__.py:1208(log)
#      4318    0.044    0.000    0.082    0.000 __init__.py:1225(findCaller)
#      4318    0.028    0.000    0.405    0.000 __init__.py:1246(makeRecord)
#      4318    0.045    0.000    1.246    0.000 __init__.py:1259(_log)
#      4318    0.029    0.000    0.714    0.000 __init__.py:1280(handle)
#      4318    0.032    0.000    0.674    0.000 __init__.py:1312(callHandlers)
#     21029    0.049    0.000    0.049    0.000 __init__.py:1338(getEffectiveLevel)
#     21029    0.096    0.000    0.145    0.000 __init__.py:1352(isEnabledFor)
#         3    0.000    0.000    0.000    0.000 __init__.py:1375(get_backend)
#         6    0.000    0.000    0.000    0.000 __init__.py:1389(is_interactive)
#      4318    0.018    0.000    0.026    0.000 __init__.py:148(getLevelName)
#     33356    0.060    0.000    0.060    0.000 __init__.py:174(get_ufc_signature)
#     16674    0.063    0.000    0.092    0.000 __init__.py:177(_checkLevel)
#     16694    0.026    0.000    0.026    0.000 __init__.py:182(get_ufc_templates_signature)
#         1    0.001    0.001    0.003    0.003 __init__.py:19(<module>)
#         8    0.000    0.000    0.003    0.000 __init__.py:193(dumps)
#        76    0.001    0.000    0.001    0.000 __init__.py:22(find_module)
#         1    0.006    0.006    0.064    0.064 __init__.py:228(<module>)
#      4318    0.161    0.000    0.378    0.000 __init__.py:237(__init__)
#         5    0.000    0.000    0.000    0.000 __init__.py:25(get_projection_class)
#       953    0.003    0.000    0.005    0.000 __init__.py:297(report)
#      4324    0.017    0.000    0.025    0.000 __init__.py:312(getMessage)
#       953    0.002    0.000    0.002    0.000 __init__.py:331(ge)
#        29    0.001    0.000    0.037    0.001 __init__.py:349(__init__)
#        29    0.000    0.000    0.000    0.000 __init__.py:359(_FuncPtr)
#        29    0.000    0.000    0.001    0.000 __init__.py:375(__getattr__)
#        29    0.000    0.000    0.000    0.000 __init__.py:382(__getitem__)
#        29    0.000    0.000    0.037    0.001 __init__.py:442(LoadLibrary)
#      4324    0.016    0.000    0.024    0.000 __init__.py:446(usesTime)
#      4324    0.033    0.000    0.083    0.000 __init__.py:452(format)
#         1    0.000    0.000    0.000    0.000 __init__.py:49(normalize_encoding)
#         1    0.001    0.001    0.006    0.006 __init__.py:52(<module>)
#         5    0.000    0.000    0.000    0.000 __init__.py:54(get_projection_class)
#      8642    0.020    0.000    0.020    0.000 __init__.py:599(filter)
#     16674    0.030    0.000    0.030    0.000 __init__.py:66(get_include_path)
#      8648    0.038    0.000    0.149    0.000 __init__.py:695(acquire)
#      4318    0.016    0.000    0.023    0.000 __init__.py:70(<lambda>)
#         5    0.000    0.000    0.000    0.000 __init__.py:70(process_projection_requirements)
#      8648    0.036    0.000    0.132    0.000 __init__.py:702(release)
#     16674    0.073    0.000    0.164    0.000 __init__.py:709(setLevel)
#         1    0.000    0.000    0.001    0.001 __init__.py:71(search_function)
#      4324    0.020    0.000    0.103    0.000 __init__.py:715(format)
#      4324    0.046    0.000    0.642    0.000 __init__.py:738(handle)
#         1    0.002    0.002    0.006    0.006 __init__.py:8(<module>)
#      4324    0.048    0.000    0.194    0.000 __init__.py:830(flush)
#      4318    0.055    0.000    0.422    0.000 __init__.py:841(emit)
#     24715    0.062    0.000    0.062    0.000 __init__.py:894(__getitem__)
#         1    0.001    0.001    0.001    0.001 __init__.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 _abcoll.py:24(_hasattr)
#         3    0.000    0.000    0.000    0.000 _abcoll.py:26(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _abcoll.py:83(__subclasshook__)
#         1    0.000    0.000    0.001    0.001 _add_newdocs.py:1(<module>)
#         4    0.000    0.000    0.001    0.000 _axes.py:135(set_title)
#         5    0.000    0.000    0.544    0.109 _axes.py:7474(tricontourf)
#        16    0.000    0.000    0.000    0.000 _base.py:1163(get_aspect)
#        18    0.000    0.000    0.000    0.000 _base.py:1166(set_aspect)
#         8    0.000    0.000    0.000    0.000 _base.py:1243(get_anchor)
#         5    0.000    0.000    0.000    0.000 _base.py:1246(set_anchor)
#         8    0.000    0.000    0.000    0.000 _base.py:1273(get_data_ratio)
#        12    0.000    0.000    0.004    0.000 _base.py:1301(apply_aspect)
#        10    0.000    0.000    0.000    0.000 _base.py:140(__init__)
#        10    0.000    0.000    0.000    0.000 _base.py:153(set_prop_cycle)
#       188    0.004    0.000    0.189    0.001 _base.py:1657(add_collection)
#         5    0.000    0.000    0.001    0.000 _base.py:1859(update_datalim)
#         5    0.000    0.000    0.000    0.000 _base.py:1896(_process_unit_info)
#         5    0.000    0.000    0.005    0.001 _base.py:2125(autoscale_view)
#         8    0.002    0.000    1.188    0.149 _base.py:2200(draw)
#        10    0.000    0.000    0.001    0.000 _base.py:2385(grid)
#         5    0.000    0.000    0.000    0.000 _base.py:2633(set_axis_on)
#         5    0.000    0.000    0.000    0.000 _base.py:2660(xaxis_inverted)
#        13    0.000    0.000    0.000    0.000 _base.py:2665(get_xbound)
#         5    0.000    0.000    0.002    0.000 _base.py:2678(set_xbound)
#        23    0.000    0.000    0.000    0.000 _base.py:2705(get_xlim)
#         5    0.000    0.000    0.002    0.000 _base.py:2711(set_xlim)
#        12    0.000    0.000    0.000    0.000 _base.py:2803(get_xscale)
#         5    0.000    0.000    0.000    0.000 _base.py:2920(yaxis_inverted)
#        13    0.000    0.000    0.000    0.000 _base.py:2925(get_ybound)
#         5    0.000    0.000    0.001    0.000 _base.py:2936(set_ybound)
#        23    0.000    0.000    0.000    0.000 _base.py:2963(get_ylim)
#         5    0.000    0.000    0.001    0.000 _base.py:2969(set_ylim)
#        12    0.000    0.000    0.000    0.000 _base.py:3062(get_yscale)
#         5    0.000    0.000    0.000    0.000 _base.py:3270(set_navigate)
#         5    0.000    0.000    0.000    0.000 _base.py:3284(set_navigate_mode)
#         5    0.000    0.000    0.000    0.000 _base.py:3564(set_cursor_props)
#        16    0.000    0.000    0.001    0.000 _base.py:3585(get_children)
#         4    0.000    0.000    0.001    0.000 _base.py:3637(get_default_bbox_extra_artists)
#         4    0.001    0.000    0.080    0.020 _base.py:3641(get_tightbbox)
#         5    0.000    0.000    0.919    0.184 _base.py:406(__init__)
#         8    0.000    0.000    0.000    0.000 _base.py:552(get_window_extent)
#         5    0.000    0.000    0.323    0.065 _base.py:559(_init_axis)
#         5    0.000    0.000    0.005    0.001 _base.py:569(set_figure)
#         5    0.000    0.000    0.003    0.001 _base.py:587(_set_lim_and_transforms)
#   920/400    0.003    0.000    0.104    0.000 _base.py:627(get_xaxis_transform)
#       100    0.001    0.000    0.018    0.000 _base.py:652(get_xaxis_text1_transform)
#       100    0.001    0.000    0.017    0.000 _base.py:678(get_xaxis_text2_transform)
#   992/440    0.003    0.000    0.104    0.000 _base.py:704(get_yaxis_transform)
#       108    0.001    0.000    0.018    0.000 _base.py:729(get_yaxis_text1_transform)
#       108    0.001    0.000    0.019    0.000 _base.py:755(get_yaxis_text2_transform)
#        10    0.000    0.000    0.013    0.001 _base.py:781(_update_transScale)
#        12    0.000    0.000    0.001    0.000 _base.py:792(get_position)
#        12    0.000    0.000    0.001    0.000 _base.py:799(set_position)
#        13    0.000    0.000    0.000    0.000 _base.py:838(set_axes_locator)
#        16    0.000    0.000    0.000    0.000 _base.py:848(get_axes_locator)
#       203    0.002    0.000    0.007    0.000 _base.py:854(_set_artist_props)
#         5    0.000    0.000    0.002    0.000 _base.py:864(_gen_axes_patch)
#         5    0.000    0.000    0.015    0.003 _base.py:880(_gen_axes_spines)
#         5    0.001    0.000    0.574    0.115 _base.py:900(cla)
#         1    0.000    0.000    0.000    0.000 _basinhopping.py:14(Storage)
#         1    0.000    0.000    0.000    0.000 _basinhopping.py:186(AdaptiveStepsize)
#         1    0.000    0.000    0.000    0.000 _basinhopping.py:253(RandomDisplacement)
#         1    0.000    0.000    0.000    0.000 _basinhopping.py:267(MinimizerWrapper)
#         1    0.000    0.000    0.000    0.000 _basinhopping.py:283(Metropolis)
#         1    0.000    0.000    0.000    0.000 _basinhopping.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _basinhopping.py:36(BasinHoppingRunner)
#         1    0.000    0.000    0.000    0.000 _differentialevolution.py:209(DifferentialEvolutionSolver)
#         1    0.000    0.000    0.000    0.000 _differentialevolution.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 _expm_multiply.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 _expm_multiply.py:284(LazyOperatorNormInfo)
#         1    0.000    0.000    0.000    0.000 _hungarian.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 _hungarian.py:110(_Hungary)
#         1    0.000    0.000    0.000    0.000 _linprog.py:16(<module>)
#      1384    0.004    0.000    0.009    0.000 _methods.py:25(_amax)
#      1317    0.004    0.000    0.009    0.000 _methods.py:28(_amin)
#        64    0.000    0.000    0.001    0.000 _methods.py:34(_prod)
#        16    0.000    0.000    0.000    0.000 _methods.py:37(_any)
#    402095    1.319    0.000    2.906    0.000 _methods.py:40(_all)
#        48    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#        48    0.001    0.000    0.002    0.000 _methods.py:53(_mean)
#         1    0.001    0.001 11474.538 11474.538 _minimize.py:36(minimize)
#         1    0.003    0.003    0.036    0.036 _minimize.py:8(<module>)
#         1    0.000    0.000    0.000    0.000 _norm.py:3(<module>)
#         1    0.001    0.001    0.002    0.002 _numdiff.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 _onenormest.py:109(_blocked_elementwise)
#         1    0.000    0.000    0.000    0.000 _onenormest.py:2(<module>)
#         4    0.000    0.000    0.000    0.000 _pylab_helpers.py:105(get_all_fig_managers)
#        16    0.000    0.000    0.000    0.000 _pylab_helpers.py:119(get_active)
#         3    0.000    0.000    0.000    0.000 _pylab_helpers.py:129(set_active)
#         3    0.000    0.000    0.000    0.000 _pylab_helpers.py:38(get_fig_manager)
#         2    0.000    0.000    0.002    0.001 _pylab_helpers.py:85(destroy_all)
#         1    0.002    0.002    0.017    0.017 _root.py:7(<module>)
#         1    0.000    0.000    0.000    0.000 _spectral.py:13(_NoConvergence)
#         1    0.000    0.000    0.000    0.000 _spectral.py:3(<module>)
#         5    0.000    0.000    0.000    0.000 _subplots.py:101(get_subplotspec)
#         5    0.000    0.000    0.002    0.000 _subplots.py:109(update_params)
#         5    0.000    0.000    0.000    0.000 _subplots.py:160(subplot_class_factory)
#         5    0.000    0.000    0.922    0.184 _subplots.py:23(__init__)
#         1    0.000    0.000    0.000    0.000 _trustregion.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _trustregion.py:14(BaseQuadraticSubproblem)
#         1    0.001    0.001    0.001    0.001 _trustregion_dogleg.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _trustregion_dogleg.py:40(DoglegSubproblem)
#         1    0.000    0.000    0.000    0.000 _trustregion_ncg.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _trustregion_ncg.py:44(CGSteihaugSubproblem)
#         7    0.000    0.000    0.001    0.000 _util.py:267(getargspec_no_self)
#      4078    0.007    0.000    0.007    0.000 _weakrefset.py:16(__init__)
#      4078    0.014    0.000    0.021    0.000 _weakrefset.py:20(__enter__)
#      4078    0.023    0.000    0.037    0.000 _weakrefset.py:26(__exit__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#        24    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#    779137    1.572    0.000    1.572    0.000 _weakrefset.py:70(__contains__)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:83(add)
#    444965    3.324    0.000    5.694    0.000 abc.py:128(__instancecheck__)
#       9/4    0.000    0.000    0.001    0.000 abc.py:148(__subclasscheck__)
#        16    0.000    0.000    0.000    0.000 access.py:192(jacobian)
#         4    0.000    0.000    0.012    0.003 access.py:36(__init__)
#        28    0.000    0.000    0.001    0.000 access.py:82(coefficient)
#      8308    0.150    0.000  133.242    0.016 ad.py:28(expand_derivatives)
#        17    0.000    0.000    0.001    0.000 add.py:17(_addsort)
#         1    0.000    0.000    0.000    0.000 add.py:334(as_coeff_Add)
#         3    0.000    0.000    0.003    0.001 add.py:350(_eval_derivative)
#         4    0.000    0.000    0.009    0.002 add.py:449(<lambda>)
#        12    0.000    0.000    0.009    0.001 add.py:450(<genexpr>)
#         4    0.000    0.000    0.003    0.001 add.py:451(<lambda>)
#        12    0.000    0.000    0.003    0.000 add.py:452(<genexpr>)
#         4    0.000    0.000    0.000    0.000 add.py:453(<lambda>)
#         8    0.000    0.000    0.000    0.000 add.py:454(<genexpr>)
#         4    0.000    0.000    0.000    0.000 add.py:455(<lambda>)
#        12    0.000    0.000    0.000    0.000 add.py:456(<genexpr>)
#         4    0.000    0.000    0.009    0.002 add.py:457(<lambda>)
#        12    0.000    0.000    0.009    0.001 add.py:458(<genexpr>)
#         4    0.000    0.000    0.002    0.000 add.py:459(<lambda>)
#        12    0.000    0.000    0.002    0.000 add.py:460(<genexpr>)
#         4    0.000    0.000    0.000    0.000 add.py:461(<lambda>)
#         8    0.000    0.000    0.000    0.000 add.py:462(<genexpr>)
#         4    0.000    0.000    0.000    0.000 add.py:463(<lambda>)
#         8    0.000    0.000    0.000    0.000 add.py:464(<genexpr>)
#         4    0.000    0.000    0.000    0.000 add.py:465(<lambda>)
#        14    0.000    0.000    0.000    0.000 add.py:466(<genexpr>)
#         4    0.000    0.000    0.038    0.010 add.py:468(_eval_is_imaginary)
#        12    0.000    0.000    0.000    0.000 add.py:469(<genexpr>)
#        12    0.000    0.000    0.032    0.003 add.py:473(<genexpr>)
#         4    0.000    0.000    0.009    0.002 add.py:478(_eval_is_odd)
#         4    0.000    0.000    0.000    0.000 add.py:485(_eval_is_irrational)
#         4    0.000    0.000    0.001    0.000 add.py:498(_eval_is_positive)
#         4    0.000    0.000    0.020    0.005 add.py:540(_eval_is_negative)
#         1    0.000    0.000    0.001    0.001 add.py:726(__neg__)
#        16    0.001    0.000    0.010    0.001 add.py:78(flatten)
#       620    0.001    0.000    0.001    0.000 adjfloat.py:103(_ad_restore_at_checkpoint)
#        12    0.000    0.000    0.001    0.000 adjfloat.py:134(__init__)
#       248    0.003    0.000    0.012    0.000 adjfloat.py:144(recompute)
#       744    0.002    0.000    0.008    0.000 adjfloat.py:145(<genexpr>)
#        62    0.001    0.000    0.001    0.000 adjfloat.py:177(evaluate_adj)
#        62    0.001    0.000    0.003    0.000 adjfloat.py:221(evaluate_adj)
#        12    0.000    0.000    0.002    0.000 adjfloat.py:24(annotated_operator)
#       213    0.001    0.000    0.001    0.000 adjfloat.py:46(__new__)
#       213    0.001    0.000    0.003    0.000 adjfloat.py:49(__init__)
#         6    0.000    0.000    0.001    0.000 adjfloat.py:68(__rmul__)
#         6    0.000    0.000    0.001    0.000 adjfloat.py:72(__add__)
#       215    0.000    0.000    0.000    0.000 adjfloat.py:99(_ad_create_checkpoint)
#    288245    5.546    0.000   24.907    0.000 algebra.py:134(__new__)
#    192180    1.130    0.000    3.902    0.000 algebra.py:180(_init)
#    192220    0.742    0.000    1.767    0.000 algebra.py:192(__init__)
#     10799    0.215    0.000    0.609    0.000 algebra.py:222(__new__)
#     10551    0.019    0.000    0.019    0.000 algebra.py:255(_init)
#     10551    0.040    0.000    0.095    0.000 algebra.py:258(__init__)
#      4242    0.087    0.000    0.230    0.000 algebra.py:281(__new__)
#      4242    0.008    0.000    0.008    0.000 algebra.py:311(_init)
#      4242    0.016    0.000    0.038    0.000 algebra.py:314(__init__)
#        26    0.000    0.000    0.000    0.000 algebra.py:336(__init__)
#     97776    1.309    0.000    5.609    0.000 algebra.py:43(__new__)
#     36472    0.066    0.000    0.066    0.000 algebra.py:92(_init)
#     36692    0.140    0.000    0.335    0.000 algebra.py:95(__init__)
#         4    0.000    0.000    0.014    0.004 analysis.py:107(extract_coefficients)
#     27915    1.866    0.000   30.278    0.001 analysis.py:113(extract_arguments_and_coefficients)
#         4    0.000    0.000    0.000    0.000 analysis.py:122(<lambda>)
#     73955    0.301    0.000    0.454    0.000 analysis.py:126(<genexpr>)
#    116312    0.354    0.000    0.513    0.000 analysis.py:135(<genexpr>)
#         8    0.000    0.000    0.002    0.000 analysis.py:139(_compute_element_numbers)
#         4    0.000    0.000    1.154    0.288 analysis.py:147(_analyze_form)
#    149/77    0.002    0.000    0.002    0.000 analysis.py:160(extract_sub_elements)
#        69    0.004    0.000    0.054    0.001 analysis.py:168(sort_elements)
#       423    0.001    0.000    0.001    0.000 analysis.py:181(<genexpr>)
#         4    0.000    0.000    0.003    0.001 analysis.py:204(_extract_representation_family)
#         8    0.000    0.000    0.000    0.000 analysis.py:216(<genexpr>)
#         4    0.000    0.000    0.003    0.001 analysis.py:254(_validate_representation_choice)
#      16/8    0.000    0.000    0.000    0.000 analysis.py:295(_has_custom_integrals)
#        16    0.000    0.000    0.000    0.000 analysis.py:301(<genexpr>)
#     20/12    0.000    0.000    0.008    0.001 analysis.py:306(_has_higher_order_geometry)
#         8    0.000    0.000    0.000    0.000 analysis.py:312(<genexpr>)
#        16    0.000    0.000    0.005    0.000 analysis.py:314(<genexpr>)
#         4    0.000    0.000    0.000    0.000 analysis.py:319(_extract_common_quadrature_degree)
#         4    0.000    0.000    0.005    0.001 analysis.py:335(_autoselect_quadrature_degree)
#         4    0.000    0.000    0.002    0.001 analysis.py:361(_check_quadrature_degree)
#         4    0.000    0.000    0.000    0.000 analysis.py:370(_extract_common_quadrature_rule)
#         4    0.000    0.000    0.001    0.000 analysis.py:384(_autoselect_quadrature_rule)
#     27915    0.101    0.000    0.647    0.000 analysis.py:39(_sorted_by_number_and_part)
#     46040    0.231    0.000    0.372    0.000 analysis.py:40(<lambda>)
#         4    0.000    0.000    0.004    0.001 analysis.py:400(_determine_representation)
#         4    0.000    0.000    0.000    0.000 analysis.py:407(<genexpr>)
#         8    0.000    0.000    0.000    0.000 analysis.py:409(<genexpr>)
#         8    0.000    0.000    0.000    0.000 analysis.py:410(<genexpr>)
#         8    0.000    0.000    0.002    0.000 analysis.py:43(unique_tuple)
#         4    0.000    0.000    0.012    0.003 analysis.py:464(_attach_integral_metadata)
#         4    0.000    0.000    0.000    0.000 analysis.py:482(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 analysis.py:528(<genexpr>)
#         4    0.000    0.000    0.000    0.000 analysis.py:552(_validate_quadrature_schemes_of_elements)
#      16/8    0.000    0.000    0.000    0.000 analysis.py:566(_get_sub_elements)
#         8    0.000    0.000    0.006    0.001 analysis.py:578(_find_compatible_representations)
#        16    0.000    0.000    0.000    0.000 analysis.py:598(<genexpr>)
#        24    0.000    0.000    0.000    0.000 analysis.py:609(<genexpr>)
#     27919    0.942    0.000   24.702    0.001 analysis.py:64(extract_type)
#    214266    2.267    0.000   22.755    0.000 analysis.py:69(<genexpr>)
#         4    0.000    0.000    1.160    0.290 analysis.py:74(analyze_ufl_objects)
#     16651    0.145    0.000   14.740    0.001 analysis.py:89(has_exact_type)
#         8    0.000    0.000    1.154    0.144 analysis.py:93(<genexpr>)
#    584270    2.343    0.000   13.394    0.000 analysis.py:98(<genexpr>)
#       248    0.004    0.000    0.299    0.001 apply_algebra_lowering.py:121(inner)
#       248    0.001    0.000    0.479    0.002 apply_algebra_lowering.py:138(determinant)
#       124    0.003    0.000    0.152    0.001 apply_algebra_lowering.py:157(nabla_grad)
#      8312    0.063    0.000   41.297    0.005 apply_algebra_lowering.py:182(apply_algebra_lowering)
#      8312    0.045    0.000    4.618    0.001 apply_algebra_lowering.py:39(__init__)
#       496    0.004    0.000    0.196    0.000 apply_algebra_lowering.py:46(trace)
# ...
#         1    0.000    0.000    0.000    0.000 traitlets.py:582(__init__)
#         4    0.000    0.000    0.000    0.000 traitlets.py:590(hold_trait_notifications)
#         2    0.000    0.000    0.002    0.001 traitlets.py:647(_notify_trait)
#         1    0.000    0.000    0.001    0.001 traitlets.py:810(traits)
#         5    0.000    0.000    0.000    0.000 transforms.py:1009(_get_minposx)
#         5    0.000    0.000    0.000    0.000 transforms.py:1013(_get_minposy)
#      3209    0.005    0.000    0.005    0.000 transforms.py:1017(get_points)
#        12    0.000    0.000    0.001    0.000 transforms.py:1035(set)
#       299    0.003    0.000    0.021    0.000 transforms.py:1065(__init__)
# 1610/1608    0.005    0.000    0.059    0.000 transforms.py:1090(get_points)
#      1101    0.006    0.000    0.092    0.000 transforms.py:1151(__add__)
#      2319    0.009    0.000    0.193    0.000 transforms.py:127(invalidate)
#       762    0.007    0.000    0.103    0.000 transforms.py:1293(transform)
# 5112/2319    0.040    0.000    0.184    0.000 transforms.py:138(_invalidate_internal)
#         8    0.000    0.000    0.001    0.000 transforms.py:1381(get_matrix)
#       448    0.004    0.000    0.060    0.000 transforms.py:1389(transform_point)
#        24    0.000    0.000    0.004    0.000 transforms.py:1403(transform_path)
#        24    0.000    0.000    0.002    0.000 transforms.py:1414(transform_path_affine)
#       312    0.004    0.000    0.025    0.000 transforms.py:1426(transform_path_non_affine)
#        10    0.000    0.000    0.001    0.000 transforms.py:1528(__init__)
#        10    0.000    0.000    0.000    0.000 transforms.py:1540(_init)
#       475    0.002    0.000    0.022    0.000 transforms.py:1579(frozen)
#        20    0.000    0.000    0.000    0.000 transforms.py:1583(_set)
#        10    0.000    0.000    0.011    0.001 transforms.py:1600(set)
#      3442    0.029    0.000    0.118    0.000 transforms.py:162(set_children)
#      1413    0.002    0.000    0.002    0.000 transforms.py:1620(_get_is_affine)
#     10565    0.040    0.000    0.274    0.000 transforms.py:1640(__init__)
#      1494    0.005    0.000    0.009    0.000 transforms.py:1644(__array__)
#        44    0.001    0.000    0.003    0.000 transforms.py:1656(__eq__)
#   934/932    0.003    0.000    0.016    0.000 transforms.py:1661(transform)
#        24    0.000    0.000    0.002    0.000 transforms.py:1678(transform_path_affine)
#      1738    0.003    0.000    0.003    0.000 transforms.py:1687(get_affine)
#      2923    0.021    0.000    0.131    0.000 transforms.py:1713(frozen)
#        40    0.000    0.000    0.000    0.000 transforms.py:1717(_get_is_separable)
#   958/956    0.007    0.000    0.013    0.000 transforms.py:1741(transform_affine)
#        28    0.000    0.000    0.002    0.000 transforms.py:1748(transform_point)
#       144    0.000    0.000    0.003    0.000 transforms.py:1769(inverted)
#      5630    0.026    0.000    0.192    0.000 transforms.py:1786(__init__)
#      5761    0.009    0.000    0.009    0.000 transforms.py:1831(get_matrix)
#         7    0.000    0.000    0.038    0.005 transforms.py:1880(clear)
#       366    0.004    0.000    0.012    0.000 transforms.py:1888(rotate)
#       366    0.002    0.000    0.013    0.000 transforms.py:1905(rotate_deg)
#       294    0.002    0.000    0.034    0.000 transforms.py:1925(rotate_deg_around)
#       588    0.005    0.000    0.024    0.000 transforms.py:1935(translate)
#      1325    0.011    0.000    0.083    0.000 transforms.py:1950(scale)
#        32    0.000    0.000    0.000    0.000 transforms.py:2003(_get_is_separable)
#       153    0.000    0.000    0.000    0.000 transforms.py:2016(frozen)
#       543    0.001    0.000    0.001    0.000 transforms.py:2023(get_matrix)
#       153    0.001    0.000    0.001    0.000 transforms.py:2027(transform)
#       153    0.000    0.000    0.000    0.000 transforms.py:2047(get_affine)
#        10    0.000    0.000    0.001    0.000 transforms.py:2068(__init__)
#       320    0.001    0.000    0.004    0.000 transforms.py:2108(_get_is_affine)
#        16    0.000    0.000    0.010    0.001 transforms.py:2116(frozen)
#       568    0.002    0.000    0.007    0.000 transforms.py:2123(transform_non_affine)
#       632    0.002    0.000    0.007    0.000 transforms.py:2154(get_affine)
#        46    0.001    0.000    0.006    0.000 transforms.py:2181(__init__)
#       587    0.002    0.000    0.006    0.000 transforms.py:2227(get_matrix)
#        56    0.000    0.000    0.007    0.000 transforms.py:2244(blended_transform_factory)
#      1125    0.008    0.000    0.077    0.000 transforms.py:2268(__init__)
#   958/479    0.013    0.000    0.209    0.000 transforms.py:2292(frozen)
#  1315/978    0.005    0.000    0.091    0.000 transforms.py:2300(_invalidate_internal)
#         8    0.000    0.000    0.000    0.000 transforms.py:2315(__eq__)
# 3231/1876    0.011    0.000    0.013    0.000 transforms.py:2331(_get_is_affine)
#       762    0.004    0.000    0.081    0.000 transforms.py:2346(transform_affine)
#       762    0.003    0.000    0.008    0.000 transforms.py:2350(transform_non_affine)
#        12    0.000    0.000    0.000    0.000 transforms.py:2360(transform_path_non_affine)
#  1244/798    0.016    0.000    0.069    0.000 transforms.py:2370(get_affine)
#     96/48    0.001    0.000    0.011    0.000 transforms.py:2378(inverted)
#       958    0.007    0.000    0.067    0.000 transforms.py:2394(__init__)
#       958    0.007    0.000    0.013    0.000 transforms.py:2438(get_matrix)
#      2059    0.019    0.000    0.168    0.000 transforms.py:2449(composite_transform_factory)
#       302    0.002    0.000    0.018    0.000 transforms.py:2528(__init__)
# 1331/1323    0.004    0.000    0.008    0.000 transforms.py:2545(get_matrix)
#         5    0.000    0.000    0.000    0.000 transforms.py:2591(__init__)
#       551    0.001    0.000    0.001    0.000 transforms.py:2604(get_matrix)
#       421    0.003    0.000    0.025    0.000 transforms.py:2626(__init__)
#       352    0.001    0.000    0.001    0.000 transforms.py:2637(get_matrix)
#       256    0.002    0.000    0.014    0.000 transforms.py:2663(__init__)
#       256    0.003    0.000    0.040    0.000 transforms.py:2680(_revalidate)
#       256    0.001    0.000    0.043    0.000 transforms.py:2694(get_transformed_points_and_affine)
#       256    0.001    0.000    0.001    0.000 transforms.py:2721(get_affine)
#        59    0.001    0.000    0.001    0.000 transforms.py:2725(nonsingular)
#        29    0.000    0.000    0.002    0.000 transforms.py:277(frozen)
#       320    0.001    0.000    0.001    0.000 transforms.py:2777(interval_contains)
#       316    0.001    0.000    0.055    0.000 transforms.py:281(__array__)
#        14    0.000    0.000    0.000    0.000 transforms.py:291(_get_x0)
#        26    0.000    0.000    0.000    0.000 transforms.py:298(_get_y0)
#         8    0.000    0.000    0.000    0.000 transforms.py:326(_get_p1)
#       620    0.003    0.000    0.008    0.000 transforms.py:333(_get_xmin)
#       612    0.003    0.000    0.006    0.000 transforms.py:338(_get_ymin)
#       620    0.003    0.000    0.006    0.000 transforms.py:343(_get_xmax)
#       624    0.003    0.000    0.006    0.000 transforms.py:348(_get_ymax)
#       136    0.001    0.000    0.001    0.000 transforms.py:366(_get_intervalx)
#       152    0.001    0.000    0.001    0.000 transforms.py:373(_get_intervaly)
#       303    0.001    0.000    0.002    0.000 transforms.py:380(_get_width)
#        46    0.000    0.000    0.000    0.000 transforms.py:387(_get_height)
#         8    0.000    0.000    0.000    0.000 transforms.py:394(_get_size)
#       219    0.002    0.000    0.004    0.000 transforms.py:401(_get_bounds)
#         4    0.000    0.000    0.000    0.000 transforms.py:408(_get_extents)
#         2    0.000    0.000    0.000    0.000 transforms.py:496(fully_overlaps)
#       153    0.002    0.000    0.011    0.000 transforms.py:518(transformed)
#       153    0.001    0.000    0.012    0.000 transforms.py:528(inverse_transformed)
#         8    0.000    0.000    0.001    0.000 transforms.py:545(anchored)
#         8    0.000    0.000    0.001    0.000 transforms.py:589(shrunk_to_aspect)
#         2    0.000    0.000    0.000    0.000 transforms.py:685(padded)
#       200    0.002    0.000    0.011    0.000 transforms.py:693(translated)
#        64    0.010    0.000    0.042    0.001 transforms.py:722(union)
#       161    0.006    0.000    0.041    0.000 transforms.py:749(intersection)
#      1514    0.016    0.000    0.100    0.000 transforms.py:780(__init__)
#       283    0.002    0.000    0.017    0.000 transforms.py:811(unit)
#         5    0.000    0.000    0.000    0.000 transforms.py:819(null)
#       409    0.002    0.000    0.057    0.000 transforms.py:827(from_bounds)
#       774    0.006    0.000    0.076    0.000 transforms.py:837(from_extents)
#     13825    0.059    0.000    0.340    0.000 transforms.py:86(__init__)
#         5    0.000    0.000    0.000    0.000 transforms.py:897(update_from_path)
#         5    0.000    0.000    0.001    0.000 transforms.py:933(update_from_data_xy)
#         5    0.000    0.000    0.000    0.000 transforms.py:987(_set_intervalx)
#         5    0.000    0.000    0.000    0.000 transforms.py:992(_set_intervaly)
#    353065    2.905    0.000    6.093    0.000 traversal.py:115(unique_post_traversal)
#   1174117   10.370    0.000   22.508    0.000 traversal.py:138(cutoff_unique_post_traversal)
#    810353   11.801    0.000   31.121    0.000 traversal.py:177(traverse_unique_terminals)
#     44570    0.247    0.000    0.391    0.000 traversal.py:31(iter_expressions)
#   1611945    3.226    0.000    3.226    0.000 traversal.py:31(pre_traversal)
#    113246    0.323    0.000    0.434    0.000 traversal.py:40(<genexpr>)
#    590594    4.355    0.000   10.899    0.000 traversal.py:94(unique_pre_traversal)
#         1    0.001    0.001    0.002    0.002 trf.py:95(<module>)
#         1    0.001    0.001    0.001    0.001 trf_linear.py:2(<module>)
#         5    0.003    0.001    0.003    0.001 triangulation.py:104(get_cpp_triangulation)
#         5    0.000    0.000    0.000    0.000 triangulation.py:122(get_from_args_and_kwargs)
#         5    0.000    0.000    0.001    0.000 triangulation.py:41(__init__)
#         5    0.000    0.000    0.544    0.109 tricontour.py:286(tricontourf)
#         5    0.000    0.000    0.544    0.109 tricontour.py:30(__init__)
#         5    0.000    0.000    0.011    0.002 tricontour.py:42(_process_args)
#         5    0.001    0.000    0.165    0.033 tricontour.py:62(_get_allsegs_and_allkinds)
#         5    0.000    0.000    0.001    0.000 tricontour.py:82(_contour_args)
#      1571    0.010    0.000    0.015    0.000 twodim_base.py:192(eye)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:35(fliplr)
#      5741    0.090    0.000    7.545    0.001 types.py:8(create_overloaded_object)
#     16190    0.026    0.000    0.026    0.000 ufl_id.py:55(_get_ufl_id)
#     19847    0.090    0.000    0.132    0.000 ufl_id.py:62(init_ufl_id)
#         1    0.000    0.000    0.000    0.000 ufl_to_cnodes.py:113(sqrt)
#         1    0.000    0.000    0.000    0.000 ufl_to_cnodes.py:194(_cmath)
#         8    0.000    0.000    0.000    0.000 ufl_to_cnodes.py:197(power)
#         4    0.000    0.000    0.000    0.000 ufl_to_cnodes.py:200(abs)
#         4    0.000    0.000    0.012    0.003 ufl_to_cnodes.py:236(__init__)
#         4    0.000    0.000    0.000    0.000 ufl_to_cnodes.py:29(__init__)
#       116    0.001    0.000    0.001    0.000 ufl_to_cnodes.py:49(float_value)
#       112    0.001    0.000    0.001    0.000 ufl_to_cnodes.py:52(int_value)
#       329    0.001    0.000    0.006    0.000 ufl_to_cnodes.py:59(sum)
#       531    0.002    0.000    0.009    0.000 ufl_to_cnodes.py:65(product)
#        75    0.000    0.000    0.001    0.000 ufl_to_cnodes.py:68(division)
# 103392/101016    0.206    0.000    0.229    0.000 ufl_type.py:213(_inherited_ufl_shape)
# 188981/169861    0.380    0.000    0.380    0.000 ufl_type.py:218(_inherited_ufl_free_indices)
# 163799/147050    0.308    0.000    0.308    0.000 ufl_type.py:221(_inherited_ufl_index_dimensions)
#    531191    2.575    0.000   11.924    0.000 ufl_type.py:39(__hash__)
#    160368    1.150    0.000    4.912    0.000 ufl_type.py:44(__eq__)
#     33510    0.184    0.000    0.621    0.000 ufl_type.py:49(__ne__)
#         4    0.000    0.000    0.549    0.137 uflacsgenerator.py:30(generate_integral_code)
#         4    0.000    0.000    0.001    0.000 uflacsoptimization.py:21(optimize_integral_ir)
#         4    0.000    0.000    0.168    0.042 uflacsrepresentation.py:110(<dictcomp>)
#         4    0.002    0.001    2.212    0.553 uflacsrepresentation.py:32(compute_integral_ir)
#         4    0.000    0.000    0.003    0.001 uflacsrepresentation.py:50(<dictcomp>)
#   126/121    0.002    0.000    0.003    0.000 units.py:125(get_converter)
#   1085332    3.467    0.000    5.601    0.000 utf_8.py:15(decode)
#         1    0.000    0.000    0.000    0.000 utils.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 utils.py:117(deprecate)
#        16    0.000    0.000    0.000    0.000 utils.py:24(generate_return_new)
#        40    0.001    0.000    0.004    0.000 utils.py:31(generate_return_new_switch)
#        12    0.000    0.000    0.000    0.000 utils.py:34(all_equal)
#        30    0.000    0.000    0.001    0.000 utils.py:38(create)
#         1    0.000    0.000    0.000    0.000 utils.py:51(_set_function_name)
#         1    0.000    0.000    0.000    0.000 utils.py:68(__init__)
#         1    0.000    0.000    0.000    0.000 utils.py:73(__call__)
#        46    0.001    0.000    0.002    0.000 uuid.py:103(__init__)
#         2    0.000    0.000    0.000    0.000 uuid.py:199(__str__)
#        16    0.000    0.000    0.000    0.000 uuid.py:267(get_hex)
#        46    0.000    0.000    0.002    0.000 uuid.py:582(uuid4)
#       228    0.002    0.000    0.055    0.000 valuenumbering.py:166(indexed)
#        87    0.001    0.000    0.022    0.000 valuenumbering.py:178(component_tensor)
#        12    0.000    0.000    0.000    0.000 valuenumbering.py:190(list_tensor)
#         8    0.000    0.000    0.014    0.002 valuenumbering.py:39(__init__)
#      1045    0.003    0.000    0.003    0.000 valuenumbering.py:46(new_symbols)
#       130    0.000    0.000    0.000    0.000 valuenumbering.py:53(new_symbol)
#       339    0.002    0.000    0.004    0.000 valuenumbering.py:59(get_node_symbols)
#      1015    0.004    0.000    0.006    0.000 valuenumbering.py:62(expr)
#        30    0.000    0.000    0.002    0.000 valuenumbering.py:67(form_argument)
#        50    0.003    0.000    0.026    0.001 valuenumbering.py:91(_modified_terminal)
#      5880    0.034    0.000    0.081    0.000 weakref.py:105(__setitem__)
#      6857    0.045    0.000    0.117    0.000 weakref.py:183(itervalues)
#      5880    0.021    0.000    0.032    0.000 weakref.py:277(__new__)
#      5880    0.015    0.000    0.015    0.000 weakref.py:282(__init__)
#        22    0.000    0.000    0.000    0.000 weakref.py:297(__init__)
#         2    0.000    0.000    0.000    0.000 weakref.py:299(remove)
#         6    0.000    0.000    0.000    0.000 weakref.py:313(_commit_removals)
#        22    0.000    0.000    0.000    0.000 weakref.py:335(__setitem__)
#        22    0.000    0.000    0.000    0.000 weakref.py:367(__contains__)
#        12    0.000    0.000    0.000    0.000 weakref.py:382(iteritems)
#     13825    0.103    0.000    0.281    0.000 weakref.py:47(__init__)
#      3469    0.007    0.000    0.007    0.000 weakref.py:55(remove)
#      4064    0.007    0.000    0.007    0.000 weakref.py:68(_commit_removals)
#         3    0.000    0.000    0.000    0.000 widgets.py:37(__init__)
#         4    0.000    0.000    0.000    0.000 wrappers.py:35(generate_wrapper_code)
#         1    0.001    0.001    0.001    0.001 zeros.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 zeros.py:20(RootResults)
#         2    0.000    0.000    0.001    0.001 zmqshell.py:68(_flush_streams)
#         2    0.000    0.000    0.009    0.004 zmqshell.py:73(publish)
