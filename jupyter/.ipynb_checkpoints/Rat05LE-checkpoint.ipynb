# %% [markdown]
# # Rat 05 forward model with linear elasticity

# %%
# %matplotlib inline
from __future__ import print_function
from dolfin import *
from dolfin_adjoint import *
import numpy as np
import os, sys
import scipy.io as scio
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import colors

# Set log level
set_log_level(40) # Error

class InterpolatedParameter(Expression):
    def __init__(self,X,Y,image,**kwargs):
        self.X = X # A numpy array giving the X-spacing of the image
        self.Y = Y # Same for Y
        self.image = image # The image of measured material property    
    def eval_cell(self,values,x,cell):
        interp_handle = RegularGridInterpolator((self.X,self.Y),self.image)
        values[0] = interp_handle(x)

def vis_obs(initial_p,target_p,label=0):
    '''
        Visualize the initial and target cellularity.
        When label >=0, the two distributions are saved to the global result file file_results
        with label=label.
    '''
    cm1 = colors.ListedColormap([[0,1,0,1],[0,0,0,1],[1,0,0,1]])    
    cm2 = cm.get_cmap('jet')
    plt.figure()
    plt.subplot(1,2,1)
    plt.title('initial')
    plot(initial_p,cmap=cm2)

    diff = Function(W,annotation=False)
    diff.rename('diff','diff tumor fraction')
    diff.vector()[:] = initial_p.vector()-target_p.vector()
 
    plt.subplot(1,2,2)
    plt.title('target')
    plot(target_p,cmap=cm2)
    plt.show()
    
    if(label >= 0):
        file_results.write(initial_p, label)
        file_results.write(target_p, label)
        file_results.write(diff, label)

def forward(initial_p,annotate=False,record=False,record_initial=False,record_target=False):
    """ 
        Here, we define the forward problem. 
        See the attached pptx file for more information on the variables.
        Don't delete the necessary adjoint-dolfin argument: annotate.
    """
    global D, alpha
    V = VectorFunctionSpace(mesh,'Lagrange',1)
    
    def boundary(x, on_boundary):
        return on_boundary

    bc = DirichletBC(V, Constant((0.0,0.0)), boundary)
    
    def E(u):
        return 0.5*(nabla_grad(u) + nabla_grad(u).T)
    def sigma(u, phi):
        return 2*mu*(E(u)-beta*phi*Identity(2))+lam*(tr(E(u))-2*beta*phi)*Identity(2)
    def vonmises(u, phi):
        s = sigma(u, phi) - (1./3)*tr(sigma(u, phi))*Identity(2)  # deviatoric stress
        von_Mises = sqrt(3./2*inner(s, s))
        return project(von_Mises, W)
    def le(phi):
        u = TrialFunction(V)
        v = TestFunction(V)
        F = -inner(sigma(u, phi), E(v))*dx 
        a, L = lhs(F), rhs(F)
        u = Function(V, name = 'u', annotate = annotate)
        solve(a == L, u, bc)
        return u

    # current distribution of cell density (phi_T)
    phi_n = Function(W, name = 'pn', annotate = annotate)
    phi_n.assign(initial_p)
    phi_n.rename('phi_T','tumor fraction')
    phi = Function(W, name = 'p', annotate = annotate)
    q = TestFunction(W)

    F = (phi - phi_n)*q*dx \
        + dt*D*dot(grad(q),grad(phi))*dx \
        - dt*alpha*phi*(1 - phi)*q*dx      

    t = 0.
    if record:
        # save the current solution, k field, initial and target solution
        file_results.write(phi_n,t)
        if record_initial:
            file_results.write(phi,t)
        if record_target:
            file_results.write(phi_2,t)

    for n in range(num_steps):
        
        disp = le(phi_n)
        vm = vonmises(disp,phi_n)
        D = Dt*exp(-gammaD*vm)
        alpha = alphat*exp(-gammaa*vm)
        
        # Update current time
        t += dt
        # Compute solution
        solve(F==0, phi, annotate = annotate) # with trivial Neumann BC
        # Update previous solution
        phi_n.assign(phi, annotate = annotate)

        if record:
            file_results.write(phi_n,t)
            if record_initial:
                file_results.write(phi,t)
            if record_target:
                file_results.write(phi2,t)
    return phi

# Callback function for the optimizer
# Writes intermediate results to a logfile
def eval_cb(j, m):
    """ The callback function keeping a log """

    print("objective = %15.10e " % j)

def objective(p, target_p):
    return assemble(inner(p-target_p, p-target_p)*dx) 

def optimize(dbg=False):
    """ The optimization routine """
    # Define the control
    #gammaD = Constant(.1)            # stress to D constant
    #gammaa = Constant(.1)            # stress to alpha constant
    m = [Control(alpha)]
    
    # Execute first time to annotate and record the tape
    p = forward(phi_0,True)

    J = objective(p, phi_2)

    # Prepare the reduced functional
    rf = ReducedFunctional(J,m,eval_cb_post=eval_cb)

    # Run the optimization
    #m_opt = minimize(rf,method='L-BFGS-B', tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
    m_opt = minimize(rf,method='L-BFGS-B', tol=1.0e-6)
    return m_opt


#########################################################################
# MAIN CODE
#########################################################################

output_dir = os.path.join('./Output/rat05') 
print('Output saved to '+output_dir)

# Prepare a mesh
mesh = Mesh("../rat-data/rat05/gmsh.xml")
W = FunctionSpace(mesh, 'CG', 1)

# Load initial tumor condition data
initial = scio.loadmat("../rat-data/rat05/ic.mat")['ic']
initial = np.fliplr(initial.T)/np.max(initial)               # Needs to be adjusted to fit the mesh correctly
x,y = initial.shape[0], initial.shape[1]
phi_0 = InterpolatedParameter(np.linspace(1,x,x),np.linspace(1,y,y),initial,degree=1)
phi_0 = interpolate(phi_0,W)    
phi_0.rename('initial','tumor at day 0')

target = scio.loadmat("../rat-data/rat05/tumor_t2.mat")['tumor']
target = np.fliplr(target.T)/np.max(target)               # Needs to be adjusted to fit the mesh correctly
x,y = target.shape[0], target.shape[1]
phi_2 = InterpolatedParameter(np.linspace(1,x,x),np.linspace(1,y,y),target,degree=1)
phi_2 = interpolate(phi_2,W)  
phi_2.rename('target','tumor at day 2')

# Model parameters
T = 1.0             # final time
num_steps = 10       # number of time steps
dt = T / num_steps    # time step size
Dt = Constant(1)      # mobility or diffusion coefficient
alphat = Constant(1)  # growth rate
gammaD = Constant(1)            # stress to D constant
gammaa = Constant(1)            # stress to alpha constant
mu, lam = 1.0, .001        # lame parameters
nu = lam/(2*(lam+mu))     # Poisson's ratio
beta = .001                  # tumor coefficient
Theta = Constant(1.0) # carrying capacity

D = interpolate(Dt,W)
alpha = interpolate(alphat,W)

# Prepare output file
file_results = XDMFFile(os.path.join(output_dir,'optimal.xdmf'))
file_results.parameters["flush_output"] = True
file_results.parameters["functions_share_mesh"] = True

# Optimization module
vis_obs(phi_0,phi_2,0) # visualize the initial and target cellularity
alpha = optimize() # optimize the k field using the adjoint method provided by adjoint_dolfin
model_p = forward(phi_0,False,True,True,True) # run the forward model using the optimized k field
print('norm(k_opt) = '+str(norm(k)))
print('J_opt = '+str(objective(model_p, phi_2, r_coeff1, r_coeff2)))
print('J_opt (without regularization) = '+str(objective(model_p, phi_2, 0., 0.)))
# Out:
# Output saved to ./Output/rat05
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-4f637d71c7eb> in <module>()
#     201 # Optimization module
#     202 vis_obs(phi_0,phi_2,0) # visualize the initial and target cellularity
# --> 203 alpha = optimize() # optimize the k field using the adjoint method provided by adjoint_dolfin
#     204 model_p = forward(phi_0,False,True,True,True) # run the forward model using the optimized k field
#     205 print('norm(k_opt) = '+str(norm(k)))
#
# <ipython-input-3-4f637d71c7eb> in optimize(dbg)
#     148     # Run the optimization
#     149     #m_opt = minimize(rf,method='L-BFGS-B', tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
# --> 150     m_opt = minimize(rf,method='L-BFGS-B', tol=1.0e-6)
#     151     return m_opt
#     152
#
# /h2/xoab/.local/lib/python2.7/site-packages/pyadjoint/tape.pyc in wrapper(*args, **kwargs)
# ...

# %% [markdown]
# Required components:
# * fenics
# * numpy for some array features
# * matplotlib not required but useful before opening paraview
# * scipy io to bring in matlab matrices
# * scipy interpolate to get initial data interpolated onto the mesh from a matrix
# * time for reaction-diffusion?
# * os for deleting/creating folders and files
# * sys for the path to get xdmf parser
# * xdmf parser to correct output

# %%
# %matplotlib inline
from fenics import *
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as scio
from scipy.interpolate import RegularGridInterpolator
import time, os, sys
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())
from xdmf_parser import xparse as xp

# %% [markdown]
# Functions needed for linear elasticity:
# * E(u) returns the Green-Lagrange strain tensor
# * sigma(...) returns the stress tensor based on the cells (phi), elasticity coefficients, and a coefficient beta
# * vonmises(...) calculates the von Mises stress
# * le(...) solves the variational problem for the displacement $u$ given the function spaces, tractions, boundary conditions, tumor cell population, and elasticity coefficients

# %%
def E(u):
    return 0.5*(nabla_grad(u) + nabla_grad(u).T)
def sigma(u, p):
    return 2*mu*(E(u)-beta*p*Identity(2))+lam*(tr(E(u))-2*beta*p)*Identity(2)
def vonmises(u, p):
    s = sigma(u, p) - (1./3)*tr(sigma(u, p))*Identity(2)  # deviatoric stress
    von_Mises = sqrt(3./2*inner(s, s))
    return project(von_Mises, W)
def le(p):
    u = TrialFunction(V)
    F = -inner(sigma(u, p), E(v))*dx + dot(T*n,v)*ds
    a, L = lhs(F), rhs(F)
    u = Function(V)
    solve(a == L, u, bc)
    return u

# %% [markdown]
# Reaction diffusion function:
# * Returns the distribution of tumor cells after a time step $dt$ given the function space, current distribution of tumor cells, diffusion coefficient, and growth coefficient

# %%
def rd():
    phi = TrialFunction(W)
    F = (1./dt)*(phi - phi_n)*q*dx \
        + D*dot(grad(q),grad(phi))*dx \
        - alpha*phi*(1 - phi)*q*dx   
    phi = Function(W)
    solve(F == 0, phi)
    return phi

# %% [markdown]
# Class to get tumor cell distributions by interpolating based off matrices of tumor cell data

# %%
class InterpolatedParameter(Expression):
    def __init__(self,X,Y,image,**kwargs):
        self.X = X # A numpy array giving the X-spacing of the image
        self.Y = Y # Same for Y
        self.image = image # The image of measured material property    
    def eval_cell(self,values,x,cell):
        interp_handle = RegularGridInterpolator((self.X,self.Y),self.image)
        values[0] = interp_handle(x)

# %%
# Create mesh and define function spaces
mesh = Mesh("../rat-data/rat05/gmsh.xml")
cf = MeshFunction("size_t",mesh,"../rat-data/rat05/gmsh_physical_region.xml")
V = VectorFunctionSpace(mesh, 'P', 2)    # Function space for displacement
W = FunctionSpace(mesh, 'P',1)           # Function space for tumor cells

# Load initial tumor condition data
tumor = scio.loadmat("../rat-data/rat05/ic.mat")['ic']
tumor = np.fliplr(tumor.T)/np.max(tumor)               # Needs to be adjusted to fit the mesh correctly
x,y = tumor.shape[0], tumor.shape[1]
phi_0 = InterpolatedParameter(np.linspace(1,x,x),np.linspace(1,y,y),tumor,degree=1)
phi_n = project(phi_0,W)                 # use the fenics project function to apply the interpolation to the DOFs

# Display initial conditions on mesh
plt.figure()
plot(mesh)
plot(phi_n,title="Initial tumor cell concentration")

# Variables
T = 1.                    # final time
num_steps = 100           # number of time steps
dt = T / num_steps        # time step size
Dt = 1.                 # Diffusion coefficient
alphat = 1.              # Reaction coeffecient
gamma1, gamma2 = .01,.01 # stress-to-diffusion/reaction coefficient
mu, lam = 1.0, 1.0        # lame parameters
nu = lam/(2*(lam+mu))     # Poisson's ratio
beta = 1                  # tumor coefficient

# Define expressions and functions used in variational forms
D = project(Constant(Dt),W)              # Diffusion constant throughout
alpha = project(Constant(alphat),W)      # Reaction constant throughout

# Define boundary condition
def boundary(x, on_boundary):
    return on_boundary
bc = DirichletBC(V, Constant((0.0,0.0)), boundary)

T = Expression((('0','0'),('0','0')),degree=1)
n = FacetNormal(mesh)

# Save output
os.system('rm ./output/rat05/*')
phifile = XDMFFile('./output/rat05/solution.xdmf')
q = TestFunction(W)
v = TestFunction(V)
disp = Function(V)
vm = Function(W)
disp.rename('u','displacement')
vm.rename('vm','Von Mises')
phi_n.rename('phi','tumor fraction')

t = 0.0
for i in range(num_steps):
    t += dt
    disp = le(phi_n)
    vm = vonmises(u,phi_n)
    D = Dt*exp(-gamma1*vm)
    alpha = alphat*exp(-gamma2*vm)
    phi = rd()
    
    # Update previous solution
    phi_n.assign(phi)
    
    # Save solution to file (xdmf)
    phifile.write(u,t)
    phifile.write(vm,t)
    phifile.write(phi_n,t)
    
del phifile
plt.figure()
plot(phi_n)
xp("output/rat05/solution.xdmf")
