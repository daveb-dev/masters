# %% [markdown]
# ## Rat 05 inverse problem with linear elasticity

# %%
# %matplotlib inline
from __future__ import print_function
from dolfin import *
from dolfin_adjoint import *
import numpy as np
import os, sys
import scipy.io as scio
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import colors

set_log_level(ERROR) 

class InterpolatedParameter(Expression):
    '''
        Class to get tumor cell distributions by interpolating based off matrices of tumor cell data
    '''
    def __init__(self,X,Y,image,**kwargs):
        self.X = X # A numpy array giving the X-spacing of the image
        self.Y = Y # Same for Y
        self.image = image # The image of measured material property    
    def eval_cell(self,values,x,cell):
        interp_handle = RegularGridInterpolator((self.X,self.Y),self.image)
        values[0] = interp_handle(x)
        
def interp(file_loc,mat_name):
    print("Interpolating "+mat_name+"...")
    mat = scio.loadmat(file_loc)[mat_name]
    mat = np.fliplr(mat.T)/theta  # Needs to be adjusted to fit the mesh correctly
    x,y = mat.shape[0], mat.shape[1]
    mat_interp = InterpolatedParameter(np.linspace(1,x,x),np.linspace(1,y,y),mat,degree=1)
    return interpolate(mat_interp,V)

def vis_obs(initial_p,target_p,title1,title2):
    '''
        Compare two quantity plots, for example initial vs. target cellularity
        Accepts titles for each plot
    '''
    print("Plotting initial condition and target...")
    target_p = interpolate(target_p,V)
    cm1 = colors.ListedColormap([[0,1,0,1],[0,0,0,1],[1,0,0,1]])    
    cm2 = cm.get_cmap('jet')
    plt.figure()
    plt.subplot(1,2,1)
    plt.title(title1)
    plot(initial_p,cmap=cm2)
 
    plt.subplot(1,2,2)
    plt.title(title2)
    plot(target_p,cmap=cm2)
    plt.show()

def forward(initial_p,record=False):
    """ 
        Here, we define the forward problem. 
    """
    '''
        - E(u) returns the Green-Lagrange strain tensor
        - sigma(...) returns the actual stress tensor
        - sigma_form(...) returns the stress tensor based on the cells (phi), elasticity coefficients, and a coefficient beta
        - vonmises(...) calculates the von Mises stress based on the actual stress tensor
    '''
    def E(u):
        return 0.5*(nabla_grad(u) + nabla_grad(u).T)
    def sigma(u):
        return 2*mu*E(u)+lmbda*tr(E(u))*Identity(2)
    def vonmises(u):
        s = sigma(u) - (1./2)*tr(sigma(u))*Identity(2)  # deviatoric stress
        von_Mises = sqrt(3./2*inner(s, s))
        return project(von_Mises, V)
    def sigma_form(u,phi):
        return 2*mu*(E(u)-beta*phi*Identity(2))+lmbda*(tr(E(u))-2*beta*phi)*Identity(2)
    
    k.rename('k','k field')              # field of growth rate, treated as a local parameter here
    p_n = Function(V) # current distribution of cell density (phi_T)
    p_n = interpolate(initial_p,V)
    p_n.rename('phi_T','tumor fraction')
    p = Function(V)
    q = TestFunction(V)
    
    U = VectorFunctionSpace(mesh,'Lagrange',1)
    parameters["form_compiler"]["quadrature_degree"] = 2
    ffc_options = {"quadrature_degree": 2}
    def boundary(x, on_boundary):
        return on_boundary
    bc = DirichletBC(U, Constant((0.,0.)), boundary)
    u = TrialFunction(U)
    v = TestFunction(U)
    F_LE = inner(sigma_form(u, p_n), E(v))*dx 
    a, L = lhs(F_LE), rhs(F_LE)
    u = Function(U)
    u.rename('u','displacement')
    def le():
        print("Solving linear elastic problem...")
        solve(a == L, u, bc, form_compiler_parameters=ffc_options)
        return u

    disp = le()
    vm = vonmises(disp)
    D = D0*exp(-gammaD*vm)
    F_RD = (1/dt)*(p - p_n)*q*dx + D*dot(grad(q),grad(p))*dx - k*p*(1 - p)*q*dx  

    # Prepare the solution
    t = 0.
#     if record:        # save the current solution, k field, displacement, and diffusion
#         file_results.write(p_n,t)
#         file_results.write(u,t)
#         file_results.write(k,t)
#         D_proj = project(D,V)
#         vm.rename("vm","Von Mises")
#         D_proj.rename("D","diffusion coefficient")
#         file_results.write(vm,t)
#         file_results.write(D_proj,t)
        
    for n in range(num_steps):
        # Update current time
        t += dt
        
        # Compute solution
        print("Solving reaction diffusion for time = "+str(t))
        solve(F_RD == 0, p) # with trivial Neumann BC

        # Update previous solution
        p_n.assign(p)
        disp = le()
        vm   = vonmises(disp)
        D    = D0*exp(-gammaD*vm)
        
        if record:        # save the current solution, k field, displacement, and diffusion
            file_results.write(p_n,t)
            file_results.write(u,t)
            file_results.write(k,t)
            D_proj = project(D,V)
            D_proj.rename("D","diffusion coefficient")
            #file_results.write(vm,t)
            file_results.write(D_proj,t)

    return p

# Callback function for the optimizer
# Writes intermediate results to a logfile
def eval_cb(j, m):
    """ The callback function keeping a log """
    print("objective = %15.10e " % j)

def objective(p, target_p, r_coeff1, r_coeff2):
    return assemble(inner(p-target_p, p-target_p)*dx) + r_coeff1*assemble(k*k*dx) + r_coeff2*assemble(dot(grad(k),grad(k))*dx)

def optimize(dbg=False):
    """ The optimization routine """
    print("Optimizing...")
    # Define the control
    m = [Control(k), Control(D0)]
    
    # Execute first time to annotate and record the tape
    p = forward(initial_p,False)

    J = objective(p, target_p, r_coeff1, r_coeff2)

    # Prepare the reduced functional
    rf = ReducedFunctional(J,m,eval_cb_post=eval_cb)
    
    # upper and lower bound for the parameter field
    k_lb, k_ub = Function(V), Function(V)
    k_lb.vector()[:] = 0.
    k_ub.vector()[:] = 20.
    D_lb = 0.0
    D_ub = 20.0
    bnds = [[k_lb,D_lb],[k_ub,D_ub]]

    # Run the optimization
    m_opt = minimize(rf,method='L-BFGS-B', bounds=bnds, tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
    
    return m_opt

#########################################################################
# MAIN 
#########################################################################
def main():
    global t1,case,r_coeff1, r_coeff2, input_dir, output_dir, file_results, mesh, V, T, num_steps,\
        dt, theta, mu, nu, lmbda, beta, gammaD, D0, k0, k, initial_p, target_p
    t1         = time()
    case       = 0
    r_coeff1   = 0.01
    r_coeff2   = 0.01
    input_dir  = "../rat-data/rat05/"
    output_dir = './output/rat05'

    # Prepare output file
    file_results = XDMFFile(os.path.join(output_dir,'optimal.xdmf'))
    file_results.parameters["flush_output"] = True
    file_results.parameters["functions_share_mesh"] = True

    # Prepare a mesh
    mesh = Mesh(input_dir+"gmsh.xml")
    V    = FunctionSpace(mesh, 'CG', 1)

    # Model parameters
    T             = .02             # final time 
    num_steps     = 2              # number of time steps
    dt            = T/num_steps     # time step size
    theta         = 50970.            # carrying capacity - normalize cell data by this 
    mu            = .42             # kPa, bulk shear modulus
    nu            = .45
    lmbda         = 2*mu*nu/(1-2*nu)
    beta          = 1.
    gammaD = Constant(2.)    # initial guess of gamma_D

    # Parameters to be optimized
    D0     = Constant(10.)   # mobility or diffusion coefficient
    k0     = Constant(2.)    # growth rate initial guess
    k      = project(k0,V)

    # Load initial tumor condition data
    initial_p = interp(input_dir+"ic.mat","ic")
    initial_p.rename('initial','tumor at day 0')
    # target_p  = interp(input_dir+"tumor_t2.mat","tumor")  
    # target_p.rename('target','tumor at day 2')

    target_p = forward(initial_p,True)

    D0     = Constant(8.)   # mobility or diffusion coefficient
    k0     = Constant(8.)    # growth rate initial guess
    k      = project(k0,V)

    # Visualize initial cellularity and target cellularity
    vis_obs(initial_p,target_p,'initial','target') 

    # Optimization module
    [k, D0] = optimize() # optimize the k field, gammaD, and D0 using the adjoint method provided by adjoint_dolfin
    model_p = forward(initial_p,False) # run the forward model using the optimized k field
    print('norm(k_opt) = '+str(norm(k)))
    print('J_opt = '+str(objective(model_p, target_p, r_coeff1, r_coeff2)))
    print('J_opt (without regularization) = '+str(objective(model_p, target_p, 0., 0.)))
    print('gamma_D = '+str(gammaD.values()[0]))
    print('D0 = '+str(D0.values()[0]))
    print('Elapsed time is ' + str((time()-t1)/60) + ' minutes')
    vis_obs(model_p,target_p,'model','actual')
    plot(k)

import profile
profile.run('main()')
# Out:
# Interpolating ic...
# Solving linear elastic problem...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving reaction diffusion for time = 0.01
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear elastic problem...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving reaction diffusion for time = 0.02
# Solving linear elastic problem...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Plotting initial condition and target...
# Optimizing...
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.01
# Solving linear elastic problem...
# Solving reaction diffusion for time = 0.02
# Solving linear elastic problem...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-18e89b698179> in <module>()
#     240
#     241 import profile
# --> 242 profile.run('main()')
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/profile.pyc in run(statement, filename, sort)
#      59     prof = Profile()
#      60     try:
# ---> 61         prof = prof.run(statement)
#      62     except SystemExit:
#      63         pass
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/profile.pyc in run(self, cmd)
#     436         import __main__
#     437         dict = __main__.__dict__
# --> 438         return self.runctx(cmd, dict, dict)
#     439
#     440     def runctx(self, cmd, globals, locals):
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/profile.pyc in runctx(self, cmd, globals, locals)
#     442         sys.setprofile(self.dispatcher)
#     443         try:
# --> 444             exec cmd in globals, locals
#     445         finally:
#     446             sys.setprofile(None)
#
# <string> in <module>()
#
# <ipython-input-8-18e89b698179> in main()
#     228
#     229     # Optimization module
# --> 230     [k, D0] = optimize() # optimize the k field, gammaD, and D0 using the adjoint method provided by adjoint_dolfin
#     231     model_p = forward(initial_p,False) # run the forward model using the optimized k field
#     232     print('norm(k_opt) = '+str(norm(k)))
#
# <ipython-input-8-18e89b698179> in optimize(dbg)
#     171
#     172     # Run the optimization
# --> 173     m_opt = minimize(rf,method='L-BFGS-B', bounds=bnds, tol=1.0e-6,options={"disp":True,"gtol":1.0e-6})
#     174
#     175     return m_opt
#
# /h2/xoab/.local/lib/python2.7/site-packages/pyadjoint/tape.pyc in wrapper(*args, **kwargs)
#      39     def wrapper(*args, **kwargs):
#      40         with stop_annotating():
# ---> 41             return function(*args, **kwargs)
#      42     return wrapper
#      43
#
# /h2/xoab/.local/lib/python2.7/site-packages/pyadjoint/optimization/optimization.pyc in minimize(rf, method, scale, **kwargs)
#     230         kwargs["method"] = method
#     231
# --> 232     opt = algorithm(rf_np, **kwargs)
#     233
#     234     if len(opt) == 1:
#
# /h2/xoab/.local/lib/python2.7/site-packages/pyadjoint/optimization/optimization.pyc in minimize_scipy_generic(rf_np, method, bounds, **kwargs)
#     131     elif bounds != None:
#     132         bounds = serialise_bounds(rf_np, bounds)
# --> 133         res = scipy_minimize(J, m_global, method=method, bounds=bounds, **kwargs)
#     134     else:
#     135         res = scipy_minimize(J, m_global, method=method, **kwargs)
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     445     elif meth == 'l-bfgs-b':
#     446         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 447                                 callback=callback, **options)
#     448     elif meth == 'tnc':
#     449         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     328                 # minimization routine wants f and g at the current x
#     329                 # Overwrite f and g:
# --> 330                 f, g = func_and_grad(x)
#     331         elif task_str.startswith(b'NEW_X'):
#     332             # new iteration
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     276     else:
#     277         def func_and_grad(x):
# --> 278             f = fun(x, *args)
#     279             g = jac(x, *args)
#     280             return f, g
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     287     def function_wrapper(*wrapper_args):
#     288         ncalls[0] += 1
# --> 289         return function(*(wrapper_args + args))
#     290
#     291     return ncalls, function_wrapper
#
# /h2/xoab/.local/lib/python2.7/site-packages/pyadjoint/reduced_functional_numpy.pyc in __call__(self, m_array)
#      56             with stop_annotating():
#      57                 for i in range(len(blocks)):
# ---> 58                     blocks[i].recompute()
#      59
#      60         return self.functional.block_variable.checkpoint
#
# /h2/xoab/.local/lib/python2.7/site-packages/pyadjoint/tape.pyc in wrapper(*args, **kwargs)
#      39     def wrapper(*args, **kwargs):
#      40         with stop_annotating():
# ---> 41             return function(*args, **kwargs)
#      42     return wrapper
#      43
#
# /h2/xoab/.local/lib/python2.7/site-packages/fenics_adjoint/solving.pyc in recompute(self)
#     483         # In theory should not matter, but may sometimes lead to
#     484         # unexpected results if not careful.
# --> 485         backend.solve(lhs == rhs, func, bcs, **self.forward_kwargs)
#     486         # Save output for use in later re-computations.
#     487         # TODO: Consider redesigning the saving system so a new deepcopy isn't created on each forward replay.
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/site-packages/dolfin/fem/solving.py in solve(*args, **kwargs)
#     298     # tolerance)
#     299     elif isinstance(args[0], ufl.classes.Equation):
# --> 300         _solve_varproblem(*args, **kwargs)
#     301
#     302     # Default case, just call the wrapped C++ solve function
#
# /opt/apps/ossw/applications/fenics-h/hashstore_gcc_6.1/bld/profile/lrxlypylraa3/lib/python2.7/site-packages/dolfin/fem/solving.py in _solve_varproblem(*args, **kwargs)
#     347         solver = NonlinearVariationalSolver(problem)
#     348         solver.parameters.update(solver_parameters)
# --> 349         solver.solve()
#     350
#     351
#
# RuntimeError:
#
# *** -------------------------------------------------------------------------
# *** DOLFIN encountered an error. If you are not able to resolve this issue
# *** using the information listed below, you can ask for help at
# ***
# ***     fenics-support@googlegroups.com
# ***
# *** Remember to include the error message listed below and, if possible,
# *** include a *minimal* running example to reproduce the error.
# ***
# *** -------------------------------------------------------------------------
# *** Error:   Unable to solve nonlinear system with NewtonSolver.
# *** Reason:  Newton solver did not converge because maximum number of iterations reached.
# *** Where:   This error was encountered inside NewtonSolver.cpp.
# *** Process: 0
# ***
# *** DOLFIN version: 2017.2.0
# *** Git changeset:
# *** -------------------------------------------------------------------------

# %%
whos
# Out:
# Variable                                  Type                             Data/Info
# ------------------------------------------------------------------------------------
# ALE                                       type                             <class 'dolfin.cpp.function.ALE'>
# AbstractCell                              type                             <class 'ufl.cell.AbstractCell'>
# AbstractDomain                            type                             <class 'ufl.domain.AbstractDomain'>
# AdaptiveLinearVariationalSolver           type                             <class 'dolfin.fem.adapti<...>LinearVariationalSolver'>
# AdaptiveNonlinearVariationalSolver        type                             <class 'dolfin.fem.adapti<...>linearVariationalSolver'>
# AdjFloat                                  type                             <class 'pyadjoint.adjfloat.AdjFloat'>
# And                                       function                         <function And at 0x7f685ba02de8>
# Argument                                  type                             <class 'dolfin.functions.function.Argument'>
# Arguments                                 function                         <function Arguments at 0x7f685ba92f50>
# Assembler                                 type                             <class 'dolfin.cpp.fem.Assembler'>
# AssemblerBase                             type                             <class 'dolfin.cpp.fem.AssemblerBase'>
# AutoSubDomain                             type                             <class 'dolfin.fem.bcs.AutoSubDomain'>
# BDF1                                      type                             <class 'dolfin.multistage.multistagescheme.BDF1'>
# BackwardEuler                             type                             <class 'dolfin.multistage.multistagescheme.BDF1'>
# BasisFunction                             type                             <class 'dolfin.cpp.fem.BasisFunction'>
# BlockMatrix                               type                             <class 'dolfin.cpp.la.BlockMatrix'>
# BlockVector                               type                             <class 'dolfin.cpp.la.BlockVector'>
# BoostGraphOrdering                        type                             <class 'dolfin.cpp.mesh.BoostGraphOrdering'>
# BoundaryMesh                              type                             <class 'dolfin.cpp.mesh.BoundaryMesh'>
# BoundingBoxTree                           type                             <class 'dolfin.cpp.mesh.BoundingBoxTree'>
# BoundingBoxTree3D                         type                             <class 'dolfin.cpp.mesh.BoundingBoxTree3D'>
# BoxMesh                                   type                             <class 'dolfin.cpp.mesh.BoxMesh'>
# BrokenElement                             type                             <class 'ufl.finiteelement<...>enelement.BrokenElement'>
# ButcherMultiStageScheme                   type                             <class 'dolfin.multistage<...>ButcherMultiStageScheme'>
# CN2                                       type                             <class 'dolfin.multistage.multistagescheme.CN2'>
# CRITICAL                                  int                              50
# Cell                                      type                             <class 'dolfin.cpp.mesh.Cell'>
# CellDiameter                              function                         <function CellDiameter at 0x7f68516bbb18>
# CellFunction                              type                             <class 'dolfin.cpp.mesh.CellFunction'>
# CellFunctionBool                          type                             <class 'dolfin.cpp.mesh.CellFunctionBool'>
# CellFunctionDouble                        type                             <class 'dolfin.cpp.mesh.CellFunctionDouble'>
# CellFunctionInt                           type                             <class 'dolfin.cpp.mesh.CellFunctionInt'>
# CellFunctionSizet                         type                             <class 'dolfin.cpp.mesh.CellFunctionSizet'>
# CellNormal                                function                         <function CellNormal at 0x7f68516bbcf8>
# CellSize                                  function                         <function CellSize at 0x7f68516bbb90>
# CellType                                  type                             <class 'dolfin.cpp.mesh.CellType'>
# CellVolume                                function                         <function CellVolume at 0x7f68516bbc08>
# Circumradius                              function                         <function Circumradius at 0x7f68516bbd70>
# Coefficient                               type                             <class 'ufl.coefficient.Coefficient'>
# Coefficients                              function                         <function Coefficients at 0x7f685ba93938>
# CollisionPredicates                       type                             <class 'dolfin.cpp.mesh.CollisionPredicates'>
# CompiledSubDomain                         function                         <function CompiledSubDomain at 0x7f68516a4aa0>
# Constant                                  type                             <class 'fenics_adjoint.types.constant.Constant'>
# Control                                   type                             <class 'pyadjoint.control.Control'>
# CoordinateMatrix                          type                             <class 'dolfin.cpp.la.CoordinateMatrix'>
# CrankNicolson                             type                             <class 'dolfin.multistage.multistagescheme.CN2'>
# D0                                        Constant                         f_348015
# DBG                                       int                              10
# DEBUG                                     int                              10
# DOLFIN_EPS                                float                            3e-16
# DOLFIN_EPS_LARGE                          float                            1e-14
# DOLFIN_LINELENGTH                         int                              256
# DOLFIN_PI                                 float                            3.14159265359
# DOLFIN_SQRT_EPS                           float                            1e-08
# DOLFIN_TERM_WIDTH                         int                              80
# DOLFIN_VERSION_GIT                        str
# DOLFIN_VERSION_MAJOR                      int                              2017
# DOLFIN_VERSION_MICRO                      int                              0
# DOLFIN_VERSION_MINOR                      int                              2
# DOLFIN_VERSION_RELEASE                    int                              1
# DOLFIN_VERSION_STRING                     str                              2017.2.0
# DefaultFactory                            type                             <class 'dolfin.cpp.la.DefaultFactory'>
# DirichletBC                               type                             <class 'fenics_adjoint.ty<...>dirichletbc.DirichletBC'>
# DiscreteOperators                         type                             <class 'dolfin.cpp.fem.DiscreteOperators'>
# Dn                                        function                         <function Dn at 0x7f685ba02500>
# DofMap                                    type                             <class 'dolfin.cpp.fem.DofMap'>
# DomainBoundary                            type                             <class 'dolfin.cpp.mesh.DomainBoundary'>
# DoubleArray                               type                             <class 'dolfin.cpp.common.DoubleArray'>
# Dx                                        function                         <function Dx at 0x7f685ba02410>
# DynamicMeshEditor                         type                             <class 'dolfin.cpp.mesh.DynamicMeshEditor'>
# ERK                                       type                             <class 'dolfin.multistage.multistagescheme.ERK1'>
# ERK1                                      type                             <class 'dolfin.multistage.multistagescheme.ERK1'>
# ERK4                                      type                             <class 'dolfin.multistage.multistagescheme.ERK4'>
# ERROR                                     int                              40
# ESDIRK3                                   type                             <class 'dolfin.multistage<...>ultistagescheme.ESDIRK3'>
# ESDIRK4                                   type                             <class 'dolfin.multistage<...>ultistagescheme.ESDIRK4'>
# Edge                                      type                             <class 'dolfin.cpp.mesh.Edge'>
# EdgeFunction                              type                             <class 'dolfin.cpp.mesh.EdgeFunction'>
# EdgeFunctionBool                          type                             <class 'dolfin.cpp.mesh.EdgeFunctionBool'>
# EdgeFunctionDouble                        type                             <class 'dolfin.cpp.mesh.EdgeFunctionDouble'>
# EdgeFunctionInt                           type                             <class 'dolfin.cpp.mesh.EdgeFunctionInt'>
# EdgeFunctionSizet                         type                             <class 'dolfin.cpp.mesh.EdgeFunctionSizet'>
# EigenFactory                              type                             <class 'dolfin.cpp.la.EigenFactory'>
# EigenKrylovSolver                         type                             <class 'dolfin.cpp.la.EigenKrylovSolver'>
# EigenLUSolver                             type                             <class 'dolfin.cpp.la.EigenLUSolver'>
# EigenMatrix                               type                             <class 'dolfin.cpp.la.EigenMatrix'>
# EigenVector                               type                             <class 'dolfin.cpp.la.EigenVector'>
# EnrichedElement                           type                             <class 'ufl.finiteelement<...>element.EnrichedElement'>
# Equation                                  type                             <class 'dolfin.cpp.fem.Equation'>
# ErrorControl                              type                             <class 'dolfin.cpp.fem.ErrorControl'>
# Event                                     type                             <class 'dolfin.cpp.common.Event'>
# ExplicitEuler                             type                             <class 'dolfin.multistage.multistagescheme.ERK1'>
# ExplicitMidPoint                          type                             <class 'dolfin.multistage<...>scheme.ExplicitMidPoint'>
# Expression                                OverloadedExpressionMetaClass    <class 'fenics_adjoint.ty<...>s.expression.Expression'>
# Extrapolation                             type                             <class 'dolfin.cpp.fem.Extrapolation'>
# FENICS_EPS                                float                            3e-16
# FENICS_EPS_LARGE                          float                            1e-14
# FENICS_PI                                 float                            3.14159265359
# FENICS_SQRT_EPS                           float                            1e-08
# Face                                      type                             <class 'dolfin.cpp.mesh.Face'>
# FaceFunction                              type                             <class 'dolfin.cpp.mesh.FaceFunction'>
# FaceFunctionBool                          type                             <class 'dolfin.cpp.mesh.FaceFunctionBool'>
# FaceFunctionDouble                        type                             <class 'dolfin.cpp.mesh.FaceFunctionDouble'>
# FaceFunctionInt                           type                             <class 'dolfin.cpp.mesh.FaceFunctionInt'>
# FaceFunctionSizet                         type                             <class 'dolfin.cpp.mesh.FaceFunctionSizet'>
# Facet                                     type                             <class 'dolfin.cpp.mesh.Facet'>
# FacetArea                                 ExpressionMetaClass              <class 'dolfin.functions.<...>cialfunctions.FacetArea'>
# FacetCell                                 type                             <class 'dolfin.cpp.mesh.FacetCell'>
# FacetElement                              function                         <function FacetElement at 0x7f685bac6938>
# FacetFunction                             type                             <class 'dolfin.cpp.mesh.FacetFunction'>
# FacetFunctionBool                         type                             <class 'dolfin.cpp.mesh.FacetFunctionBool'>
# FacetFunctionDouble                       type                             <class 'dolfin.cpp.mesh.FacetFunctionDouble'>
# FacetFunctionInt                          type                             <class 'dolfin.cpp.mesh.FacetFunctionInt'>
# FacetFunctionSizet                        type                             <class 'dolfin.cpp.mesh.FacetFunctionSizet'>
# FacetNormal                               function                         <function FacetNormal at 0x7f68516bb9b0>
# File                                      type                             <class 'dolfin.cpp.io.File'>
# FiniteElement                             type                             <class 'ufl.finiteelement<...>teelement.FiniteElement'>
# FiniteElementBase                         type                             <class 'ufl.finiteelement<...>tbase.FiniteElementBase'>
# Form                                      type                             <class 'dolfin.fem.form.Form'>
# ForwardEuler                              type                             <class 'dolfin.multistage.multistagescheme.ERK1'>
# Function                                  type                             <class 'fenics_adjoint.types.function.Function'>
# FunctionAXPY                              type                             <class 'dolfin.cpp.function.FunctionAXPY'>
# FunctionAssigner                          type                             <class 'dolfin.cpp.function.FunctionAssigner'>
# FunctionSpace                             type                             <class 'fenics_adjoint.ty<...>es.compat.FunctionSpace'>
# GRL1                                      type                             <class 'dolfin.multistage<...>.rushlarsenschemes.GRL1'>
# GRL2                                      type                             <class 'dolfin.multistage<...>.rushlarsenschemes.GRL2'>
# GenericAdaptiveVariationalSolver          type                             <class 'dolfin.cpp.fem.Ge<...>aptiveVariationalSolver'>
# GenericBoundingBoxTree                    type                             <class 'dolfin.cpp.mesh.GenericBoundingBoxTree'>
# GenericDofMap                             type                             <class 'dolfin.cpp.fem.GenericDofMap'>
# GenericFile                               type                             <class 'dolfin.cpp.io.GenericFile'>
# GenericFunction                           type                             <class 'dolfin.cpp.function.GenericFunction'>
# GenericLinearAlgebraFactory               type                             <class 'dolfin.cpp.la.Gen<...>ricLinearAlgebraFactory'>
# GenericLinearOperator                     type                             <class 'dolfin.cpp.la.GenericLinearOperator'>
# GenericLinearSolver                       type                             <class 'dolfin.cpp.la.GenericLinearSolver'>
# GenericMatrix                             type                             <class 'dolfin.cpp.la.GenericMatrix'>
# GenericTensor                             type                             <class 'dolfin.cpp.la.GenericTensor'>
# GenericVector                             type                             <class 'dolfin.cpp.la.GenericVector'>
# GlobalParameters                          type                             <class 'dolfin.cpp.common.GlobalParameters'>
# Graph                                     type                             <class 'dolfin.cpp.mesh.Graph'>
# GraphBuilder                              type                             <class 'dolfin.cpp.mesh.GraphBuilder'>
# H1                                        SobolevSpace                     H1
# H2                                        SobolevSpace                     H2
# HCurl                                     SobolevSpace                     HCurl
# HCurlElement                              type                             <class 'ufl.finiteelement.hdivcurl.HCurlElement'>
# HDF5Attribute                             type                             <class 'dolfin.cpp.io.HDF5Attribute'>
# HDF5File                                  type                             <class 'dolfin.cpp.io.HDF5File'>
# HDiv                                      SobolevSpace                     HDiv
# HDivElement                               type                             <class 'ufl.finiteelement.hdivcurl.HDivElement'>
# HierarchicalDirichletBC                   type                             <class 'dolfin.cpp.fem.HierarchicalDirichletBC'>
# HierarchicalErrorControl                  type                             <class 'dolfin.cpp.fem.HierarchicalErrorControl'>
# HierarchicalForm                          type                             <class 'dolfin.cpp.fem.HierarchicalForm'>
# HierarchicalFunction                      type                             <class 'dolfin.cpp.fem.HierarchicalFunction'>
# HierarchicalFunctionSpace                 type                             <class 'dolfin.cpp.fem.Hi<...>erarchicalFunctionSpace'>
# HierarchicalLinearVariationalProblem      type                             <class 'dolfin.cpp.fem.Hi<...>inearVariationalProblem'>
# HierarchicalMesh                          type                             <class 'dolfin.cpp.fem.HierarchicalMesh'>
# HierarchicalMeshFunctionBool              type                             <class 'dolfin.cpp.mesh.H<...>rchicalMeshFunctionBool'>
# HierarchicalMeshFunctionDouble            type                             <class 'dolfin.cpp.mesh.H<...>hicalMeshFunctionDouble'>
# HierarchicalMeshFunctionInt               type                             <class 'dolfin.cpp.mesh.H<...>archicalMeshFunctionInt'>
# HierarchicalMeshFunctionSizet             type                             <class 'dolfin.cpp.mesh.H<...>chicalMeshFunctionSizet'>
# HierarchicalMeshFunctionUInt              type                             <class 'dolfin.cpp.mesh.H<...>rchicalMeshFunctionUInt'>
# HierarchicalNonlinearVariationalProblem   type                             <class 'dolfin.cpp.fem.Hi<...>inearVariationalProblem'>
# INFO                                      int                              20
# IPOPTSolver                               type                             <class 'pyadjoint.optimiz<...>popt_solver.IPOPTSolver'>
# Identity                                  type                             <class 'ufl.constantvalue.Identity'>
# ImplicitEuler                             type                             <class 'dolfin.multistage.multistagescheme.BDF1'>
# Index                                     type                             <class 'ufl.core.multiindex.Index'>
# IndexMap                                  type                             <class 'dolfin.cpp.la.IndexMap'>
# IndexSet                                  type                             <class 'dolfin.cpp.common.IndexSet'>
# InequalityConstraint                      type                             <class 'pyadjoint.optimiz<...>ts.InequalityConstraint'>
# IntArray                                  type                             <class 'dolfin.cpp.common.IntArray'>
# Integral                                  type                             <class 'ufl.integral.Integral'>
# InteriorElement                           function                         <function InteriorElement at 0x7f685bac6aa0>
# InterpolatedParameter                     OverloadedExpressionMetaClass    <class '__main__.InterpolatedParameter'>
# IntervalMesh                              type                             <class 'dolfin.cpp.mesh.IntervalMesh'>
# Jacobian                                  type                             <class 'ufl.geometry.Jacobian'>
# JacobianDeterminant                       type                             <class 'ufl.geometry.JacobianDeterminant'>
# JacobianInverse                           type                             <class 'ufl.geometry.JacobianInverse'>
# KrylovSolver                              type                             <class 'dolfin.cpp.la.KrylovSolver'>
# L2                                        SobolevSpace                     L2
# LUSolver                                  type                             <class 'fenics_adjoint.lusolver.LUSolver'>
# Lagrange                                  type                             <class 'dolfin.cpp.function.Lagrange'>
# LagrangeInterpolator                      type                             <class 'dolfin.cpp.functi<...>on.LagrangeInterpolator'>
# Legendre                                  type                             <class 'dolfin.cpp.function.Legendre'>
# LinearAlgebraObject                       type                             <class 'dolfin.cpp.la.LinearAlgebraObject'>
# LinearOperator                            type                             <class 'dolfin.cpp.la.LinearOperator'>
# LinearSolver                              type                             <class 'dolfin.cpp.la.LinearSolver'>
# LinearVariationalProblem                  type                             <class 'fenics_adjoint.va<...>inearVariationalProblem'>
# LinearVariationalSolver                   type                             <class 'fenics_adjoint.va<...>LinearVariationalSolver'>
# LocalAssembler                            type                             <class 'dolfin.cpp.fem.LocalAssembler'>
# LocalMeshData                             type                             <class 'dolfin.cpp.mesh.LocalMeshData'>
# LocalSolver                               type                             <class 'dolfin.fem.solving.LocalSolver'>
# MPI                                       type                             <class 'dolfin.cpp.common.MPI'>
# MPICH_IGNORE_CXX_SEEK                     int                              1
# MPIInfo                                   type                             <class 'dolfin.cpp.common.MPIInfo'>
# MPI_Comm                                  type                             <class 'dolfin.cpp.common.MPI_Comm'>
# Matrix                                    type                             <class 'dolfin.cpp.la.Matrix'>
# Max                                       function                         <function Max at 0x7f685ba07140>
# MaxCellEdgeLength                         function                         <function MaxCellEdgeLength at 0x7f68516bbe60>
# MaxFacetEdgeLength                        function                         <function MaxFacetEdgeLength at 0x7f68516bbf50>
# Measure                                   type                             <class 'ufl.measure.Measure'>
# Mesh                                      type                             <class 'dolfin.cpp.mesh.Mesh'>
# MeshColoring                              type                             <class 'dolfin.cpp.mesh.MeshColoring'>
# MeshConnectivity                          type                             <class 'dolfin.cpp.mesh.MeshConnectivity'>
# MeshCoordinates                           ExpressionMetaClass              <class 'dolfin.functions.<...>nctions.MeshCoordinates'>
# MeshData                                  type                             <class 'dolfin.cpp.mesh.MeshData'>
# MeshDisplacement                          type                             <class 'dolfin.cpp.function.MeshDisplacement'>
# MeshDomains                               type                             <class 'dolfin.cpp.mesh.MeshDomains'>
# MeshEditor                                type                             <class 'dolfin.cpp.mesh.MeshEditor'>
# MeshEntity                                type                             <class 'dolfin.cpp.mesh.MeshEntity'>
# MeshFunction                              type                             <class 'dolfin.cpp.mesh.MeshFunction'>
# MeshFunctionBool                          type                             <class 'dolfin.cpp.mesh.MeshFunctionBool'>
# MeshFunctionDouble                        type                             <class 'dolfin.cpp.mesh.MeshFunctionDouble'>
# MeshFunctionInt                           type                             <class 'dolfin.cpp.mesh.MeshFunctionInt'>
# MeshFunctionSizet                         type                             <class 'dolfin.cpp.mesh.MeshFunctionSizet'>
# MeshGeometry                              type                             <class 'dolfin.cpp.mesh.MeshGeometry'>
# MeshHierarchy                             type                             <class 'dolfin.cpp.mesh.MeshHierarchy'>
# MeshPartitioning                          type                             <class 'dolfin.cpp.mesh.MeshPartitioning'>
# MeshPointIntersection                     type                             <class 'dolfin.cpp.mesh.MeshPointIntersection'>
# MeshQuality                               type                             <class 'dolfin.cpp.mesh.MeshQuality'>
# MeshRenumbering                           type                             <class 'dolfin.cpp.mesh.MeshRenumbering'>
# MeshTopology                              type                             <class 'dolfin.cpp.mesh.MeshTopology'>
# MeshTransformation                        type                             <class 'dolfin.cpp.mesh.MeshTransformation'>
# MeshValueCollection                       type                             <class 'dolfin.cpp.mesh.MeshValueCollection'>
# MeshValueCollectionBool                   type                             <class 'dolfin.cpp.mesh.MeshValueCollectionBool'>
# MeshValueCollectionDouble                 type                             <class 'dolfin.cpp.mesh.M<...>shValueCollectionDouble'>
# MeshValueCollectionInt                    type                             <class 'dolfin.cpp.mesh.MeshValueCollectionInt'>
# MeshValueCollectionSizet                  type                             <class 'dolfin.cpp.mesh.M<...>eshValueCollectionSizet'>
# MeshView                                  type                             <class 'ufl.domain.MeshView'>
# Min                                       function                         <function Min at 0x7f685ba071b8>
# MinCellEdgeLength                         function                         <function MinCellEdgeLength at 0x7f68516bbde8>
# MinFacetEdgeLength                        function                         <function MinFacetEdgeLength at 0x7f68516bbed8>
# MinimizationProblem                       type                             <class 'pyadjoint.optimiz<...>lem.MinimizationProblem'>
# MixedElement                              type                             <class 'ufl.finiteelement<...>xedelement.MixedElement'>
# MultiMesh                                 type                             <class 'dolfin.cpp.mesh.MultiMesh'>
# MultiMeshAssembler                        type                             <class 'dolfin.cpp.fem.MultiMeshAssembler'>
# MultiMeshDirichletBC                      type                             <class 'dolfin.cpp.fem.MultiMeshDirichletBC'>
# MultiMeshDofMap                           type                             <class 'dolfin.cpp.fem.MultiMeshDofMap'>
# MultiMeshForm                             type                             <class 'dolfin.cpp.fem.MultiMeshForm'>
# MultiMeshFunction                         type                             <class 'dolfin.functions.<...>ction.MultiMeshFunction'>
# MultiMeshFunctionSpace                    function                         <function MultiMeshFuncti<...>nSpace at 0x7f68516d7488>
# MultiMeshSubSpace                         type                             <class 'dolfin.cpp.function.MultiMeshSubSpace'>
# MultiStageScheme                          type                             <class 'dolfin.multistage<...>scheme.MultiStageScheme'>
# NewtonSolver                              type                             <class 'fenics_adjoint.ne<...>ton_solver.NewtonSolver'>
# NodalEnrichedElement                      type                             <class 'ufl.finiteelement<...>nt.NodalEnrichedElement'>
# NonlinearProblem                          type                             <class 'dolfin.cpp.la.NonlinearProblem'>
# NonlinearVariationalProblem               type                             <class 'fenics_adjoint.va<...>inearVariationalProblem'>
# NonlinearVariationalSolver                type                             <class 'fenics_adjoint.va<...>linearVariationalSolver'>
# Not                                       function                         <function Not at 0x7f685ba02ed8>
# OptimisationProblem                       type                             <class 'dolfin.cpp.la.OptimisationProblem'>
# Or                                        function                         <function Or at 0x7f685ba02e60>
# PETScBaseMatrix                           type                             <class 'dolfin.cpp.la.PETScBaseMatrix'>
# PETScDMCollection                         type                             <class 'dolfin.cpp.fem.PETScDMCollection'>
# PETScFactory                              type                             <class 'dolfin.cpp.la.PETScFactory'>
# PETScKrylovSolver                         type                             <class 'dolfin.cpp.la.PETScKrylovSolver'>
# PETScLUSolver                             type                             <class 'dolfin.cpp.la.PETScLUSolver'>
# PETScLinearOperator                       type                             <class 'dolfin.cpp.la.PETScLinearOperator'>
# PETScMatrix                               type                             <class 'dolfin.cpp.la.PETScMatrix'>
# PETScObject                               type                             <class 'dolfin.cpp.la.PETScObject'>
# PETScOptions                              type                             <class 'dolfin.cpp.la.PETScOptions'>
# PETScPreconditioner                       type                             <class 'dolfin.cpp.la.PETScPreconditioner'>
# PETScSNESSolver                           type                             <class 'dolfin.cpp.la.PETScSNESSolver'>
# PETScTAOSolver                            type                             <class 'dolfin.cpp.la.PETScTAOSolver'>
# PETScVector                               type                             <class 'dolfin.cpp.la.PETScVector'>
# PROGRESS                                  int                              16
# ParameterValue                            type                             <class 'dolfin.cpp.common.ParameterValue'>
# Parameters                                type                             <class 'dolfin.cpp.common.Parameters'>
# PeriodicBoundaryComputation               type                             <class 'dolfin.cpp.mesh.P<...>odicBoundaryComputation'>
# PermutationSymbol                         type                             <class 'ufl.constantvalue.PermutationSymbol'>
# Point                                     type                             <class 'dolfin.cpp.mesh.Point'>
# PointIntegralSolver                       type                             <class 'dolfin.multistage<...>ers.PointIntegralSolver'>
# PointSource                               type                             <class 'dolfin.cpp.fem.PointSource'>
# Progress                                  type                             <class 'dolfin.cpp.common.Progress'>
# RK4                                       type                             <class 'dolfin.multistage.multistagescheme.ERK4'>
# RKSolver                                  type                             <class 'dolfin.multistage<...>tistagesolvers.RKSolver'>
# RL1                                       type                             <class 'dolfin.multistage.rushlarsenschemes.RL1'>
# RL2                                       type                             <class 'dolfin.multistage.rushlarsenschemes.RL2'>
# RectangleMesh                             type                             <class 'dolfin.cpp.mesh.RectangleMesh'>
# ReducedFunctional                         type                             <class 'pyadjoint.reduced<...>ional.ReducedFunctional'>
# RegularGridInterpolator                   type                             <class 'scipy.interpolate<...>RegularGridInterpolator'>
# RestrictedElement                         type                             <class 'ufl.finiteelement<...>ement.RestrictedElement'>
# RushLarsenScheme                          type                             <class 'dolfin.multistage<...>chemes.RushLarsenScheme'>
# SCOTCH                                    type                             <class 'dolfin.cpp.mesh.SCOTCH'>
# SLEPcEigenSolver                          type                             <class 'dolfin.cpp.la.SLEPcEigenSolver'>
# Scalar                                    type                             <class 'dolfin.cpp.la.Scalar'>
# SparsityPattern                           type                             <class 'dolfin.cpp.la.SparsityPattern'>
# SparsityPatternBuilder                    type                             <class 'dolfin.cpp.fem.SparsityPatternBuilder'>
# SpatialCoordinate                         function                         <function SpatialCoordinate at 0x7f68516bbc80>
# SpecialFacetFunction                      type                             <class 'dolfin.cpp.functi<...>on.SpecialFacetFunction'>
# SphericalShellMesh                        type                             <class 'dolfin.cpp.mesh.SphericalShellMesh'>
# SubDomain                                 type                             <class 'dolfin.cpp.mesh.SubDomain'>
# SubMesh                                   type                             <class 'dolfin.cpp.mesh.SubMesh'>
# SubSystemsManager                         type                             <class 'dolfin.cpp.common.SubSystemsManager'>
# SubsetIterator                            type                             <class 'dolfin.cpp.mesh.SubsetIterator'>
# SystemAssembler                           type                             <class 'dolfin.fem.assembling.SystemAssembler'>
# T                                         float                            0.02
# TAOLinearBoundSolver                      type                             <class 'dolfin.cpp.la.TAOLinearBoundSolver'>
# TRACE                                     int                              13
# Table                                     type                             <class 'dolfin.cpp.common.Table'>
# TableEntry                                type                             <class 'dolfin.cpp.common.TableEntry'>
# Tape                                      type                             <class 'pyadjoint.tape.Tape'>
# TensorConstant                            function                         <function TensorConstant at 0x7f685ba938c0>
# TensorElement                             type                             <class 'ufl.finiteelement<...>edelement.TensorElement'>
# TensorFunctionSpace                       function                         <function TensorFunctionSpace at 0x7f68516d7410>
# TensorLayout                              type                             <class 'dolfin.cpp.la.TensorLayout'>
# TensorProductCell                         type                             <class 'ufl.cell.TensorProductCell'>
# TensorProductElement                      type                             <class 'ufl.finiteelement<...>nt.TensorProductElement'>
# TensorProductMesh                         type                             <class 'ufl.domain.TensorProductMesh'>
# TestFunction                              function                         <function TestFunction at 0x7f68516d7c80>
# TestFunctions                             function                         <function TestFunctions at 0x7f68516bc758>
# Time                                      classobj                         dolfin.common.time.Time
# TimeSeries                                type                             <class 'dolfin.cpp.fem.TimeSeries'>
# Timer                                     type                             <class 'dolfin.common.timer.Timer'>
# TimingClear_clear                         bool                             True
# TimingClear_keep                          bool                             False
# TimingType_system                         int                              2
# TimingType_user                           int                              1
# TimingType_wall                           int                              0
# TrialFunction                             function                         <function TrialFunction at 0x7f68516bc668>
# TrialFunctions                            function                         <function TrialFunctions at 0x7f68516bc7d0>
# UFC_SIGNATURE                             str                              88dddf3c76205f56f0a292f2288f49b009b54ca5
# UFC_VERSION                               str                              2017.2.0.dev0
# UFC_VERSION_MAINTENANCE                   int                              0
# UFC_VERSION_MAJOR                         int                              2017
# UFC_VERSION_MINOR                         int                              2
# UFC_VERSION_RELEASE                       int                              0
# UFLException                              type                             <class 'ufl.log.UFLException'>
# UIntArray                                 type                             <class 'dolfin.cpp.common.UIntArray'>
# UnitCubeMesh                              type                             <class 'dolfin.cpp.mesh.UnitCubeMesh'>
# UnitDiscMesh                              type                             <class 'dolfin.cpp.mesh.UnitDiscMesh'>
# UnitIntervalMesh                          type                             <class 'dolfin.cpp.mesh.UnitIntervalMesh'>
# UnitSquareMesh                            type                             <class 'dolfin.cpp.mesh.UnitSquareMesh'>
# UnitTetrahedronMesh                       type                             <class 'dolfin.cpp.mesh.UnitTetrahedronMesh'>
# UnitTriangleMesh                          type                             <class 'dolfin.cpp.mesh.UnitTriangleMesh'>
# UserExpression                            ExpressionMetaClass              <class 'dolfin.functions.expression.Expression'>
# V                                         FunctionSpace                    <Function space of dimens<...>78 (<CG1 on a triangle>)>
# Variable                                  type                             <class 'dolfin.cpp.common.Variable'>
# Vector                                    type                             <class 'dolfin.cpp.la.Vector'>
# VectorConstant                            function                         <function VectorConstant at 0x7f685ba932a8>
# VectorElement                             type                             <class 'ufl.finiteelement<...>edelement.VectorElement'>
# VectorFunctionSpace                       function                         <function VectorFunctionSpace at 0x7f68516a4c08>
# VectorSpaceBasis                          type                             <class 'dolfin.cpp.la.VectorSpaceBasis'>
# Vertex                                    type                             <class 'dolfin.cpp.mesh.Vertex'>
# VertexFunction                            type                             <class 'dolfin.cpp.mesh.VertexFunction'>
# VertexFunctionBool                        type                             <class 'dolfin.cpp.mesh.VertexFunctionBool'>
# VertexFunctionDouble                      type                             <class 'dolfin.cpp.mesh.VertexFunctionDouble'>
# VertexFunctionInt                         type                             <class 'dolfin.cpp.mesh.VertexFunctionInt'>
# VertexFunctionSizet                       type                             <class 'dolfin.cpp.mesh.VertexFunctionSizet'>
# WARNING                                   int                              30
# X3DOM                                     type                             <class 'dolfin.cpp.io.X3DOM'>
# X3DOMParameters                           type                             <class 'dolfin.cpp.io.X3DOMParameters'>
# XDMFFile                                  type                             <class 'dolfin.cpp.io.XDMFFile'>
# acos                                      function                         <function acos at 0x7f685ba076e0>
# action                                    function                         <function action at 0x7f685b9aa050>
# adapt                                     function                         <function adapt at 0x7f68515fa8c0>
# adapt_markers                             function                         <function adapt_markers at 0x7f68515fa5f0>
# add_logfile                               instancemethod                   <bound method Logger.add_<...>tance at 0x7f685be28320>>
# adjoint                                   function                         <function adjoint at 0x7f68516e9c08>
# as_backend_type                           function                         <function as_backend_type at 0x7f6851f0d5f0>
# as_cell                                   function                         <function as_cell at 0x7f685bb07cf8>
# as_domain                                 function                         <function as_domain at 0x7f685bacc320>
# as_matrix                                 function                         <function as_matrix at 0x7f685ba92230>
# as_tensor                                 function                         <function as_tensor at 0x7f685ba921b8>
# as_ufl                                    function                         <function as_ufl at 0x7f685ba899b0>
# as_vector                                 function                         <function as_vector at 0x7f685ba922a8>
# asin                                      function                         <function asin at 0x7f685ba07758>
# assemble                                  function                         <function assemble at 0x7f68520f19b0>
# assemble_local                            function                         <function assemble_local at 0x7f68516e9e60>
# assemble_multimesh                        function                         <function assemble_multimesh at 0x7f68516e91b8>
# assemble_system                           function                         <function assemble_system at 0x7f68520f7230>
# assembly                                  module                           <module 'fenics_adjoint.a<...>cs_adjoint/assembly.pyc'>
# assign                                    function                         <function assign at 0x7f68515f5848>
# atan                                      function                         <function atan at 0x7f685ba077d0>
# atan_2                                    function                         <function atan_2 at 0x7f685ba07848>
# avg                                       function                         <function avg at 0x7f685ba028c0>
# backend                                   module                           <module 'fenics' from '/o<...>ages/fenics/__init__.py'>
# begin                                     function                         <function begin at 0x7f685a74b938>
# bessel_I                                  function                         <function bessel_I at 0x7f685ba07a28>
# bessel_J                                  function                         <function bessel_J at 0x7f685ba07938>
# bessel_K                                  function                         <function bessel_K at 0x7f685ba07aa0>
# bessel_Y                                  function                         <function bessel_Y at 0x7f685ba079b0>
# beta                                      float                            1.0
# between                                   function                         <function between at 0x7f68515e3c08>
# block_split                               function                         <function block_split at 0x7f685b9a9d70>
# case                                      int                              0
# cell_avg                                  function                         <function cell_avg at 0x7f685ba02938>
# cells                                     type                             <class 'dolfin.cpp.mesh.cells'>
# cm                                        module                           <module 'matplotlib.cm' f<...>kages/matplotlib/cm.pyc'>
# cofac                                     function                         <function cofac at 0x7f685ba020c8>
# colors                                    module                           <module 'matplotlib.color<...>s/matplotlib/colors.pyc'>
# common                                    module                           <module 'dolfin.common' f<...>lfin/common/__init__.py'>
# compile_expressions                       function                         <function compile_expressions at 0x7f68516a47d0>
# compile_extension_module                  function                         <function compile_extensi<...>module at 0x7f68516a4578>
# compilemodules                            module                           <module 'dolfin.compilemo<...>pilemodules/__init__.py'>
# compute_edge_map                          function                         <function compute_edge_map at 0x7f68516c7578>
# compute_gradient                          function                         <function compute_gradient at 0x7f6852225b18>
# compute_hessian                           function                         <function compute_hessian at 0x7f6852225c80>
# compute_vertex_map                        function                         <function compute_vertex_map at 0x7f68516c7500>
# conditional                               function                         <function conditional at 0x7f685ba02aa0>
# continue_annotation                       function                         <function continue_annotation at 0x7f685224a320>
# cos                                       function                         <function cos at 0x7f685ba07410>
# cosh                                      function                         <function cosh at 0x7f685ba07578>
# cpp                                       module                           <module 'dolfin.cpp' from<...>/dolfin/cpp/__init__.py'>
# create_mesh                               function                         <function create_mesh at 0x7f68521d5c08>
# cross                                     function                         <function cross at 0x7f685ba03ed8>
# curl                                      function                         <function curl at 0x7f685ba027d0>
# custom_integral_types                     tuple                            n=4
# dC                                        Measure                          dC(subdomain_id=everywhere)
# dI                                        Measure                          dI(subdomain_id=everywhere)
# dO                                        Measure                          dO(subdomain_id=everywhere)
# dP                                        Measure                          dP(subdomain_id=everywhere)
# dS                                        Measure                          dS(subdomain_id=everywhere)
# dS_h                                      Measure                          dS_h(subdomain_id=everywhere)
# dS_v                                      Measure                          dS_v(subdomain_id=everywhere)
# dX                                        MeasureSum                       {\n    dx(subdomain_id=ev<...>bdomain_id=everywhere)\n}
# dc                                        Measure                          dc(subdomain_id=everywhere)
# debug                                     function                         <function debug at 0x7f685a74ef50>
# deprecation                               module                           <module 'dolfin.deprecati<...>s/dolfin/deprecation.py'>
# derivative                                function                         <function derivative at 0x7f68516e9c80>
# det                                       function                         <function det at 0x7f685ba03f50>
# dev                                       function                         <function dev at 0x7f685ba022a8>
# diag                                      function                         <function diag at 0x7f685ba021b8>
# ...
# list_linear_solver_methods                function                         <function list_linear_sol<...>ethods at 0x7f6851f0a758>
# list_lu_solver_methods                    function                         <function list_lu_solver_<...>ethods at 0x7f6851f0a7d0>
# list_timings                              function                         <function list_timings at 0x7f685a7465f0>
# lmbda                                     float                            3.78
# ln                                        function                         <function ln at 0x7f685ba07398>
# log                                       function                         <function log at 0x7f685a74b8c0>
# lt                                        function                         <function lt at 0x7f685ba02cf8>
# lu_solver_methods                         function                         <function lu_solver_methods at 0x7f6851f0ac08>
# lusolver                                  module                           <module 'fenics_adjoint.l<...>cs_adjoint/lusolver.pyc'>
# main                                      function                         <function main at 0x7f683a49e7d0>
# make_ufc_coordinate_mapping               builtin_function_or_method       <built-in function make_ufc_coordinate_mapping>
# make_ufc_dofmap                           builtin_function_or_method       <built-in function make_ufc_dofmap>
# make_ufc_finite_element                   builtin_function_or_method       <built-in function make_ufc_finite_element>
# make_ufc_form                             builtin_function_or_method       <built-in function make_ufc_form>
# mark                                      function                         <function mark at 0x7f68515fa938>
# max_value                                 function                         <function max_value at 0x7f685ba07050>
# memory_usage                              function                         <function memory_usage at 0x7f68516042a8>
# mesh                                      Mesh                             <Mesh of topological dime<...>and 19627 cells, ordered>
# min_value                                 function                         <function min_value at 0x7f685ba070c8>
# minimize                                  function                         <function wrapper at 0x7f685223a500>
# monitor_memory_usage                      function                         <function monitor_memory_usage at 0x7f685a74e0c8>
# mpi_comm_self                             builtin_function_or_method       <built-in function mpi_comm_self>
# mpi_comm_world                            builtin_function_or_method       <built-in function mpi_comm_world>
# mu                                        float                            0.42
# multistage                                module                           <module 'dolfin.multistag<...>/multistage/__init__.py'>
# nabla_div                                 function                         <function nabla_div at 0x7f685ba02758>
# nabla_grad                                function                         <function nabla_grad at 0x7f685ba026e0>
# ne                                        function                         <function ne at 0x7f685ba02b90>
# near                                      function                         <function near at 0x7f68515e3b90>
# newton_solver                             module                           <module 'fenics_adjoint.n<...>joint/newton_solver.pyc'>
# norm                                      function                         <function norm at 0x7f68516e9578>
# normalize                                 function                         <function normalize at 0x7f6851f0ade8>
# not_working_in_parallel                   function                         <function not_working_in_<...>rallel at 0x7f685a74e050>
# np                                        module                           <module 'numpy' from '/op<...>ages/numpy/__init__.pyc'>
# nu                                        float                            0.45
# num_steps                                 int                              2
# objective                                 function                         <function objective at 0x7f683a49e488>
# old_init                                  instancemethod                   <unbound method Parameters.__init__>
# optimize                                  function                         <function optimize at 0x7f683a64e938>
# os                                        module                           <module 'os' from '/opt/a<...>a3/lib/python2.7/os.pyc'>
# outer                                     function                         <function outer at 0x7f685ba03c08>
# output_dir                                str                              ./output/rat05
# p                                         Index                            i_4
# p_refine                                  function                         <function p_refine at 0x7f68515f4938>
# parameters                                Parameters                       <Parameter set "dolfin" c<...>(s) and parameter set(s)>
# pause_annotation                          function                         <function pause_annotation at 0x7f685224a2a8>
# perp                                      function                         <function perp at 0x7f685ba03e60>
# pi                                        float                            3.14159265359
# plot                                      function                         <function plot at 0x7f6851604320>
# plt                                       module                           <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# print_function                            __future__._Feature              _Feature((2, 6, 0, 'alpha<...>0, 0, 'alpha', 0), 65536)
# product                                   function                         <function product at 0x7f685bda96e0>
# profile                                   module                           <module 'profile' from '/<...>b/python2.7/profile.pyc'>
# project                                   function                         <function project at 0x7f68520f77d0>
# projection                                module                           <module 'fenics_adjoint.p<...>_adjoint/projection.pyc'>
# pyadjoint                                 module                           <module 'pyadjoint' from <...>/pyadjoint/__init__.pyc'>
# q                                         Index                            i_5
# quadrilateral                             Cell                             quadrilateral
# r                                         Index                            i_6
# r_coeff1                                  float                            0.01
# r_coeff2                                  float                            0.01
# rand                                      function                         <function rand at 0x7f68515e3aa0>
# rank                                      function                         <function rank at 0x7f685b9f1410>
# refine                                    function                         <function refine at 0x7f68516c7668>
# register_element                          function                         <function register_element at 0x7f685bb1ec08>
# register_integral_type                    function                         <function register_integr<...>l_type at 0x7f685ba6b500>
# relabel                                   function                         <function relabel at 0x7f685ba92410>
# replace                                   function                         <function replace at 0x7f685b9af0c8>
# replace_integral_domains                  function                         <function replace_integra<...>omains at 0x7f685b9f1050>
# residual                                  function                         <function residual at 0x7f6851f0ad70>
# rhs                                       function                         <function rhs at 0x7f685b9a9e60>
# rot                                       function                         <function curl at 0x7f685ba027d0>
# s                                         Index                            i_7
# scio                                      module                           <module 'scipy.io' from '<...>s/scipy/io/__init__.pyc'>
# seed                                      function                         <function seed at 0x7f68515e3b18>
# sensitivity_rhs                           function                         <function sensitivity_rhs at 0x7f685b9aa398>
# set_coordinates                           function                         <function set_coordinates at 0x7f68521d5d70>
# set_indentation_level                     function                         <function set_indentation<...>_level at 0x7f685a74e230>
# set_log_active                            function                         <function set_log_active at 0x7f685a74ba28>
# set_log_level                             function                         <function set_log_level at 0x7f685a74bc80>
# set_output_stream                         function                         <function set_output_stream at 0x7f685a74e1b8>
# set_working_tape                          function                         <function set_working_tape at 0x7f685224a230>
# shape                                     function                         <function shape at 0x7f685ba03410>
# show_elements                             function                         <function show_elements at 0x7f685baacb18>
# sign                                      function                         <function sign at 0x7f685ba02f50>
# sin                                       function                         <function sin at 0x7f685ba07488>
# sinh                                      function                         <function sinh at 0x7f685ba075f0>
# sizeof_la_index                           function                         <function sizeof_la_index at 0x7f685a72ed70>
# skew                                      function                         <function skew at 0x7f685ba02320>
# solve                                     function                         <function solve at 0x7f68520f72a8>
# solving                                   module                           <module 'fenics_adjoint.s<...>ics_adjoint/solving.pyc'>
# split                                     function                         <function split at 0x7f685bacca28>
# sqr                                       function                         <function sqr at 0x7f6851604848>
# sqrt                                      function                         <function sqrt at 0x7f685ba072a8>
# string_types                              tuple                            n=1
# supported_elements                        list                             n=20
# supported_elements_for_plotting           list                             n=25
# sym                                       function                         <function sym at 0x7f685ba02398>
# sys                                       module                           <module 'sys' (built-in)>
# system                                    function                         <function system at 0x7f685b9a9ed8>
# t1                                        float                            169203.772433
# tan                                       function                         <function tan at 0x7f685ba07500>
# tanh                                      function                         <function tanh at 0x7f685ba07668>
# tape                                      Tape                             <pyadjoint.tape.Tape object at 0x7f68520f3be8>
# target_p                                  Function                         f_347751
# taylor_test                               function                         <function taylor_test at 0x7f6852225cf8>
# taylor_test_multiple                      function                         <function taylor_test_multiple at 0x7f6852232c80>
# tear                                      function                         <function tear at 0x7f68516e9de8>
# tetrahedron                               Cell                             tetrahedron
# theta                                     float                            50970.0
# tic                                       function                         <function tic at 0x7f685a746410>
# time                                      function                         <function time at 0x7f685a746500>
# timed                                     function                         <function timed at 0x7f68516049b0>
# timing                                    function                         <function timing at 0x7f685a7466e0>
# timings                                   function                         <function timings at 0x7f685a746578>
# toc                                       function                         <function toc at 0x7f685a746488>
# tr                                        function                         <function tr at 0x7f685ba02140>
# transpose                                 function                         <function transpose at 0x7f685ba03b90>
# triangle                                  Cell                             triangle
# types                                     module                           <module 'fenics_adjoint.t<...>oint/types/__init__.pyc'>
# ufc_cell                                  type                             <class 'dolfin.cpp.fem.ufc_cell'>
# ufc_coordinate_mapping                    type                             <class 'dolfin.cpp.fem.ufc_coordinate_mapping'>
# ufc_dofmap                                type                             <class 'dolfin.cpp.fem.ufc_dofmap'>
# ufc_finite_element                        type                             <class 'dolfin.cpp.fem.ufc_finite_element'>
# ufc_form                                  type                             <class 'dolfin.cpp.fem.ufc_form'>
# ufc_function                              type                             <class 'dolfin.cpp.fem.ufc_function'>
# ufc_shape_hexahedron                      int                              4
# ufc_shape_interval                        int                              0
# ufc_shape_quadrilateral                   int                              2
# ufc_shape_tetrahedron                     int                              3
# ufc_shape_triangle                        int                              1
# ufc_signature                             function                         <function ufc_signature at 0x7f685a72ec80>
# ui                                        module                           <module 'fenics_adjoint.u<...>s/fenics_adjoint/ui.pyc'>
# unit_matrices                             function                         <function unit_matrices at 0x7f685ba926e0>
# unit_matrix                               function                         <function unit_matrix at 0x7f685ba92668>
# unit_vector                               function                         <function unit_vector at 0x7f685ba92578>
# unit_vectors                              function                         <function unit_vectors at 0x7f685ba925f0>
# variable                                  function                         <function variable at 0x7f685ba02a28>
# variational_solver                        module                           <module 'fenics_adjoint.v<...>/variational_solver.pyc'>
# vertex                                    Cell                             vertex
# vertex_to_dof_map                         function                         <function vertex_to_dof_map at 0x7f68521d5cf8>
# vertices                                  type                             <class 'dolfin.cpp.mesh.vertices'>
# vis_obs                                   function                         <function vis_obs at 0x7f68398c7140>
# warning                                   function                         <function warning at 0x7f685a74b6e0>
# zero                                      function                         <function zero at 0x7f685ba89938>
